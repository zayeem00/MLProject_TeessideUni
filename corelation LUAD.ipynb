# %%
import pandas as pd
import os
from sklearn.metrics import r2_score

# %%
os.chdir('U:\\More Data')

# %%
dt=pd.read_excel('LUAD_250_NoDepth.xlsx')

# %%
sur=pd.read_excel('survival_LUAD.xlsx')

# %%
x=dt[["American Joint Committee on Cancer Tumor Stage Code"]]

# %%
y=sur[['Survival ']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=101)
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train,y_train)
predictions=lm.predict(X_test)
plt.figure(figsize=(20,10))
plt.scatter(y_test,predictions)
plt.xlabel('true value')
plt.ylabel('predicted value')
plt.title("American Joint Committee on Cancer Tumor Stage Code")
# Out:
# Text(0.5,1,'American Joint Committee on Cancer Tumor Stage Code')

# %%
import scipy

# %%
from scipy import stats

# %%
from scipy.stats import pearsonr
from scipy.stats import spearmanr

# %%
pearsonr(x,y)
# Out:
# (array([-0.17951096]), array([4.0402125e-05]))

# %%
spearmanr(x,y)
# Out:
# SpearmanrResult(correlation=-0.18933926011996371, pvalue=1.4644463082549402e-05)

# %%
import seaborn

# %%
from seaborn import swarmplot

# %%
x=np.array(x)
x=x.flatten()
y=np.array(y)
y=y.flatten()

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(20,10))
swarmplot(x,y);
plt.xlabel('American Joint Committee on Cancer Tumor Stage Code')
plt.ylabel('Survival Rate')
# Out:
# Text(0,0.5,'Survival Rate')

# %%
plt.figure(figsize=(20,10))
seaborn.boxplot(x,y)

# %%
seaborn.barplot(x,y)

# %%
a=dt[["Days to Sample Collection"]]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=101)
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train,y_train)
predictions=lm.predict(X_test)
plt.figure(figsize=(20,10))
plt.scatter(y_test,predictions)
plt.xlabel('true value')
plt.ylabel('predicted value')
plt.title("Days to Sample Collection")
# Out:
# Text(0.5,1,'Days to Sample Collection')

# %%
spearmanr(a,y)
# Out:
# SpearmanrResult(correlation=0.2089558063521992, pvalue=1.6457921894540413e-06)

# %%
x=dt[["Neoplasm Disease Stage American Joint Committee on Cancer Code3"]]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=101)

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train,y_train)
predictions=lm.predict(X_test)
plt.figure(figsize=(20,10))
plt.scatter(y_test,predictions)
plt.xlabel('true value')
plt.ylabel('predicted value')
plt.title("Neoplasm Disease Stage American Joint Committee on Cancer Code3")
# Out:
# Text(0.5,1,'Neoplasm Disease Stage American Joint Committee on Cancer Code3')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=101)
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train,y_train)
predictions=lm.predict(X_test)
plt.figure(figsize=(20,10))
plt.scatter(y_test,predictions)
plt.xlabel('true value')
plt.ylabel('predicted value')
plt.title("Neoplasm Disease Stage American Joint Committee on Cancer Code3")

# %%
spearmanr(x,y)
# Out:
# SpearmanrResult(correlation=-0.1339466175926135, pvalue=0.0022730587533528164)

# %%
x=dt[["Days to Sample Collection"]]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=101)
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train,y_train)
predictions=lm.predict(X_test)
plt.figure(figsize=(20,10))
plt.scatter(y_test,predictions)
plt.xlabel('true value')
plt.ylabel('predicted value')
plt.title("Neoplasm Disease Stage American Joint Committee on Cancer Code3")
# Out:
# Text(0.5,1,'Neoplasm Disease Stage American Joint Committee on Cancer Code3')

# %%
spearmanr(x,y)
# Out:
# SpearmanrResult(correlation=0.2089558063521992, pvalue=1.6457921894540413e-06)

# %%
x=dt[["Tissue Prospective Collection Indicator"]]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=101)
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train,y_train)
predictions=lm.predict(X_test)
plt.figure(figsize=(20,10))
plt.scatter(y_test,predictions)
plt.xlabel('true value')
plt.ylabel('predicted value')
plt.title("Tissue Prospective Collection Indicator")
# Out:
# Text(0.5,1,'Tissue Prospective Collection Indicator')

# %%
spearmanr(x,y)
# Out:
# SpearmanrResult(correlation=-0.24185201803389925, pvalue=2.5662955662410356e-08)

# %%
dt.corr()

# %%
x=dt[["Tissue Retrospective Collection Indicator"]]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=101)
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train,y_train)
predictions=lm.predict(X_test)
plt.figure(figsize=(20,10))
plt.scatter(y_test,predictions)
plt.xlabel('true value')
plt.ylabel('predicted value')
plt.title("Tissue Retrospective Collection Indicator")
# Out:
# Text(0.5,1,'Tissue Retrospective Collection Indicator')

# %%
spearmanr(x,y)
# Out:
# SpearmanrResult(correlation=0.24185201803389925, pvalue=2.5662955662410356e-08)
