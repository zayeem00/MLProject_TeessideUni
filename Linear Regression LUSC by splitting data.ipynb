# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn import linear_model

# %%
os.chdir('U:\\ProjectDataset')

# %%
tar=pd.read_excel('survival_LUSC.xlsx')

# %%
import numpy as np
from sklearn import linear_model

# %%
from sklearn.model_selection import train_test_split

# %%
Y=tar

# %%
X_train,X_test,Y_train,Y_test=train_test_split(dt,Y,test_size=0.3)
print(X_train.shape,Y_train.shape)
print(X_test.shape,Y_test.shape)
# Out:
# (350, 19) (350, 1)
# (151, 19) (151, 1)

# %%
lm=linear_model.LinearRegression()
model=lm.fit(X_train,Y_train)
predictionss=lm.predict(X_test)

# %%
predictionss[0:5]
# Out:
# array([[21.70081672],
#        [17.57662232],
#        [23.43666003],
#        [34.66260366],
#        [20.76227576]])

# %%
model.score(X_test,Y_test)
# Out:
# 0.6169553732281294

# %%
mse=np.mean((predictionss-Y_test)**2)

# %%
print(mse)
# Out:
# Overall Survival    446.951105
# dtype: float64

# %%
plt.figure(figsize=(20,10))
plt.title('Predictions LUSC Linear Regression')
plt.scatter(Y_test,predictionss)

# %%
from sklearn import metrics

# %%
from sklearn.metrics import mean_squared_error

# %%
rm=np.sqrt(mean_squared_error(Y_test,predictionss))
print(rm)
# Out:
# 21.14121814211156

# %%
plt.figure(figsize=(20,10))
plt.title('Residual Plot ')
x_plot=plt.scatter(predictionss,(predictionss-Y_test)) 
#plt.hlines(y=0,xmin=-1000,xmax=5000)

# %%
from pandas import Series
predictors=X_train.columns
plt.figure(figsize=(20,10))
plt.title('Variable Coefficients')
coef=Series(c,predictors).sort_values()
coef.plot(kind='bar')
