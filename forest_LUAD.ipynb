# %% [markdown]
# <a href="https://colab.research.google.com/github/zayeem00/MLProject_TeessideUni/blob/master/forest_LUAD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-2729cc4a-ec76-4e62-9c22-8e09b2e788e5" name="files[]" multiple disabled />
#      <output id="result-2729cc4a-ec76-4e62-9c22-8e09b2e788e5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving LUAD.xlsx to LUAD (8).xlsx
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-5c2e8a8d365b> in <module>()
#       1 from google.colab import files
# ----> 2 files.upload()
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in upload()
#      70     result = _output.eval_js(
#      71         'google.colab._files._uploadFilesContinue("{output_id}")'.format(
# ---> 72             output_id=output_id))
# ...

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-3484ec5d-105c-421c-9703-5869bd646332" name="files[]" multiple disabled />
#      <output id="result-3484ec5d-105c-421c-9703-5869bd646332">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving survival_LUAD.xlsx to survival_LUAD.xlsx
# ...

# %%
y=pd.read_excel('survival_LUAD.xlsx')

# %%
dt=pd.read_excel('LUAD (7).xlsx',index_col=0)

# %%
column=dt.columns

# %%
len(column)
# Out:
# 14828

# %%
print(dt.isnull().values.any())
# Out:
# False

# %%
import numpy as np
y=np.array(y)
y=y.ravel()

# %%
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor(random_state=1,max_depth=10)
dt=pd.get_dummies(dt)
model.fit(dt,y)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=10,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#            oob_score=False, random_state=1, verbose=0, warm_start=False)

# %%
import numpy as np
features = dt.columns
importances = model.feature_importances_
plt.figure(figsize=(20,30))
indices = np.argsort(importances)[-350:]  # top 100 features
plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %%
len(features)
# Out:
# 350

# %%
features=[features[i] for i in indices]

# %%
len(features)
# Out:
# 350

# %%
importances=importances[indices]

# %%
all(i>0 for i in importances)
# Out:
# True

# %%
importances=importances[importances>0]

# %%
column=dt.columns

# %%
len(column)
# Out:
# 14828

# %%
importances[importances>=0.0001]

# %%
imp=list(features[importances>=0.0001])

# %%
imp=pd.DataFrame(imp)

# %%
len(importances)
# Out:
# 14090

# %%
all( i>=0 for i in importances)
# Out:
# True

# %%
len(column)
# Out:
# 9863

# %%
for i in column:
  if(i in features):
    print('yes')
  else:
    del dt[i]
# Out:
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# ...

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).

# %%
dt.shape
# Out:
# (517, 350)

# %%
drive.mount("drive", force_remount=True)
# Out:
# Mounted at drive

# %%
dt.to_excel('LUAD_F.xlsx')
# !cp LUAD_F.xlsx drive/My\ Drive/

# %%
from google.colab import files

dt.to_excel('df.xlsx')
files.download('df.xlsx')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-171-4c56dba4f5e9> in <module>()
#       1 from google.colab import files
#       2
# ----> 3 dt.to_excel('df.xlsx')
#       4 files.download('df.xlsx')
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    1543                 except Exception:
#    1544                     result_index = index
# -> 1545
#    1546         if any(exclude):
#    1547             arr_exclude = [x for x in exclude if x in arr_columns]
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/formats/excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
# ...
