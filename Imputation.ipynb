# %% [markdown]
# <a href="https://colab.research.google.com/github/zayeem00/MLProject_TeessideUni/blob/master/Imputation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

from sklearn.base import TransformerMixin

class DataFrameImputer(TransformerMixin):

    def __init__(self):
        """Impute missing values.

        Columns of dtype object are imputed with the most frequent value 
        in column.

        Columns of other types are imputed with mean of column.

        """
    def fit(self, X, y=None):

        self.fill = pd.Series([X[c].value_counts().index[0]
            if X[c].dtype == np.dtype('O') else X[c].mean() for c in X],
            index=X.columns)

        return self

    def transform(self, X, y=None):
        return X.fillna(self.fill)
X=pd.read_excel('LUAD_Clinical_FilteredData.xlsx')
xt = DataFrameImputer().fit_transform(X)

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at drive

# %%
xt.to_excel('LUAD_Filtered.xlsx')
# !cp LUAD_Filtered.xlsx drive/My\ Drive/

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-e68401b8-685d-441f-b78d-b109bad513eb" name="files[]" multiple disabled />
#      <output id="result-e68401b8-685d-441f-b78d-b109bad513eb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving LUAD_Clinical_FilteredData.xlsx to LUAD_Clinical_FilteredData.xlsx
# ...

# %%
import numpy
import pandas 

from sklearn.base import TransformerMixin

class SeriesImputer(TransformerMixin):

    def __init__(self):
        """Impute missing values.

        If the Series is of dtype Object, then impute with the most frequent object.
        If the Series is not of dtype Object, then impute with the mean.  

        """
    def fit(self, X, y=None):
        if   X.dtype == numpy.dtype('O'): self.fill = X.value_counts().index[0]
        else                            : self.fill = X.mean()
        return self

    def transform(self, X, y=None):
       return X.fillna(self.fill)
X=pd.read_excel('LUAD_Clinical_FilteredData.xlsx')
xt = DataFrameImputer().fit_transform(X)
xt
# Out:
#            Sample ID  Shortest Dimension  Longest Dimension  \
# 0    TCGA-05-4244-01            0.300000           1.100000
# 1    TCGA-05-4249-01            0.400000           1.400000
# 2    TCGA-05-4250-01            0.300000           1.200000
# 3    TCGA-05-4382-01            0.300000           0.900000
# 4    TCGA-05-4384-01            0.400000           0.800000
# 5    TCGA-05-4389-01            0.300000           1.300000
# 6    TCGA-05-4390-01            0.300000           1.800000
# 7    TCGA-05-4395-01            0.400000           1.000000
# 8    TCGA-05-4396-01            0.500000           1.600000
# 9    TCGA-05-4397-01            0.500000           0.900000
# 10   TCGA-05-4398-01            0.400000           1.500000
# 11   TCGA-05-4402-01            0.200000           1.600000
# 12   TCGA-05-4403-01            0.400000           1.500000
# 13   TCGA-05-4405-01            0.300000           0.900000
# 14   TCGA-05-4410-01            0.400000           1.000000
# ...
