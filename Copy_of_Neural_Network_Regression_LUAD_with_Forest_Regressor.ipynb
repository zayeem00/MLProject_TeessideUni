# %% [markdown]
# <a href="https://colab.research.google.com/github/zayeem00/MLProject_TeessideUni/blob/master/Copy_of_Neural_Network_Regression_LUAD_with_Forest_Regressor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error 
from matplotlib import pyplot as plt
import seaborn as sb
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)
from xgboost import XGBRegressor
from sklearn.model_selection import RepeatedKFold

# %%
from google.colab import files
files.upload()

# %%
import pandas as pd
Y_test=pd.read_excel('LUAD_Survival_testset.xlsx')
Y_train=pd.read_excel('survival_LUAD_Trainset.xlsx')
X_train=pd.read_excel('LUAD_320features_train.xlsx',index_col=0)    
X_test=pd.read_excel('LUAD_320features_test.xlsx',index_col=0)

# %%
import numpy as np 
X_train=np.array(X_train)
Y_train=np.array(Y_train)
X_test=np.array(X_test)
Y_train=np.array(Y_train)

# %%
NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = X_train.shape[1], activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(300, kernel_initializer='random_uniform',activation='relu'))
NN_model.add(Dense(300, kernel_initializer='random_uniform',activation='relu'))
NN_model.add(Dense(300, kernel_initializer='random_uniform',activation='relu'))
NN_model.add(Dense(300, kernel_initializer='random_uniform',activation='relu'))
NN_model.add(Dense(300, kernel_initializer='random_uniform',activation='relu'))
NN_model.add(Dense(300, kernel_initializer='random_uniform',activation='relu'))
#NN_model.add(Dense(300, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
#NN_model.summary()
checkpoint_name = 'Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]
NN_model.fit(X_train, Y_train, epochs=250, batch_size=32, validation_split = 0.3,callbacks=callbacks_list) 
predictions = NN_model.predict(X_test)
from sklearn.metrics import r2_score
accuracy=r2_score(Y_test,predictions)
print('test')
print(accuracy)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_17 (Dense)             (None, 128)               41088
# _________________________________________________________________
# dense_18 (Dense)             (None, 300)               38700
# _________________________________________________________________
# dense_19 (Dense)             (None, 300)               90300
# _________________________________________________________________
# dense_20 (Dense)             (None, 300)               90300
# _________________________________________________________________
# dense_21 (Dense)             (None, 300)               90300
# _________________________________________________________________
# dense_22 (Dense)             (None, 300)               90300
# _________________________________________________________________
# dense_23 (Dense)             (None, 300)               90300
# ...

# %%
checkpoint_name = 'Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]

# %%
NN_model.fit(X_train, Y_train, epochs=250, batch_size=32, validation_split = 0.3,callbacks=callbacks_list)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 291 samples, validate on 126 samples
# Epoch 1/250
# 291/291 [==============================] - 1s 4ms/step - loss: 27.0187 - mean_absolute_error: 27.0187 - val_loss: 17.1377 - val_mean_absolute_error: 17.1377
#
# Epoch 00001: val_loss improved from inf to 17.13765, saving model to Weights-001--17.13765.hdf5
# Epoch 2/250
# 291/291 [==============================] - 0s 504us/step - loss: 22.5463 - mean_absolute_error: 22.5463 - val_loss: 21.1124 - val_mean_absolute_error: 21.1124
#
# Epoch 00002: val_loss did not improve from 17.13765
# Epoch 3/250
# 291/291 [==============================] - 0s 510us/step - loss: 22.3268 - mean_absolute_error: 22.3268 - val_loss: 14.4088 - val_mean_absolute_error: 14.4088
#
# ...

# %%
predictions = NN_model.predict(X_test)
from sklearn.metrics import r2_score
accuracy=r2_score(Y_test,predictions)
print('test')
print(accuracy)
# Out:
# test
# -3.8515824953587243

# %%
NN_model = Sequential()
# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = X_train.shape[1], activation='relu'))
# The Hidden Layers :
NN_model.add(Dense(300, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(300, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(300, kernel_initializer='normal',activation='relu'))
# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))
# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
#NN_model.summary()
checkpoint_name = 'Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]
NN_model.fit(X_train, Y_train, epochs=100, batch_size=32, validation_split = 0.3,callbacks=callbacks_list) 
predictions = NN_model.predict(X_test)
# Out:
# Train on 291 samples, validate on 126 samples
# Epoch 1/100
# 291/291 [==============================] - 1s 5ms/step - loss: 26.6430 - mean_absolute_error: 26.6430 - val_loss: 14.6178 - val_mean_absolute_error: 14.6178
#
# Epoch 00001: val_loss improved from inf to 14.61783, saving model to Weights-001--14.61783.hdf5
# Epoch 2/100
# 291/291 [==============================] - 0s 293us/step - loss: 22.3407 - mean_absolute_error: 22.3407 - val_loss: 14.5727 - val_mean_absolute_error: 14.5727
#
# Epoch 00002: val_loss improved from 14.61783 to 14.57268, saving model to Weights-002--14.57268.hdf5
# Epoch 3/100
# 291/291 [==============================] - 0s 305us/step - loss: 21.4661 - mean_absolute_error: 21.4661 - val_loss: 20.8101 - val_mean_absolute_error: 20.8101
#
# Epoch 00003: val_loss did not improve from 14.57268
# Epoch 4/100
# ...

# %%
r2_score(Y_test,predictions)
# Out:
# -2.233852289409357

# %%
                                                                                  ''' On Adding one more hidden layer'''
  
NN_model = Sequential()
# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = X_train.shape[1], activation='relu'))
# The Hidden Layers :
NN_model.add(Dense(300, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(300, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(300, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(300, kernel_initializer='normal',activation='relu'))
# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))
# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
#NN_model.summary()
checkpoint_name = 'Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]
NN_model.fit(X_train, Y_train, epochs=100, batch_size=32, validation_split = 0.3,callbacks=callbacks_list) 
predictions = NN_model.predict(X_test)
# Out:
# Train on 291 samples, validate on 126 samples
# Epoch 1/100
# 291/291 [==============================] - 2s 5ms/step - loss: 24.0566 - mean_absolute_error: 24.0566 - val_loss: 15.0972 - val_mean_absolute_error: 15.0972
#
# Epoch 00001: val_loss improved from inf to 15.09718, saving model to Weights-001--15.09718.hdf5
# Epoch 2/100
# 291/291 [==============================] - 0s 345us/step - loss: 21.9915 - mean_absolute_error: 21.9915 - val_loss: 14.4584 - val_mean_absolute_error: 14.4584
#
# Epoch 00002: val_loss improved from 15.09718 to 14.45837, saving model to Weights-002--14.45837.hdf5
# Epoch 3/100
# 291/291 [==============================] - 0s 349us/step - loss: 22.7198 - mean_absolute_error: 22.7198 - val_loss: 14.4987 - val_mean_absolute_error: 14.4987
#
# Epoch 00003: val_loss did not improve from 14.45837
# Epoch 4/100
# ...

# %%
r2_score(Y_test,predictions)
# Out:
# -0.995915417331815

# %%
                                                                                  ''' On Adding one more hidden layer'''
  
NN_model = Sequential()
# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = X_train.shape[1], activation='relu'))
# The Hidden Layers :
NN_model.add(Dense(300, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(300, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(300, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(300, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(300, kernel_initializer='normal',activation='relu'))
# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))
# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
#NN_model.summary()
checkpoint_name = 'Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]
NN_model.fit(X_train, Y_train, epochs=100, batch_size=32, validation_split = 0.3,callbacks=callbacks_list) 
predictions = NN_model.predict(X_test)
# Out:
# Train on 291 samples, validate on 126 samples
# Epoch 1/100
# 291/291 [==============================] - 2s 6ms/step - loss: 25.9843 - mean_absolute_error: 25.9843 - val_loss: 14.8604 - val_mean_absolute_error: 14.8604
#
# Epoch 00001: val_loss improved from inf to 14.86042, saving model to Weights-001--14.86042.hdf5
# Epoch 2/100
# 291/291 [==============================] - 0s 454us/step - loss: 21.4377 - mean_absolute_error: 21.4377 - val_loss: 15.8455 - val_mean_absolute_error: 15.8455
#
# Epoch 00002: val_loss did not improve from 14.86042
# Epoch 3/100
# 291/291 [==============================] - 0s 454us/step - loss: 21.2222 - mean_absolute_error: 21.2222 - val_loss: 16.3541 - val_mean_absolute_error: 16.3541
#
# Epoch 00003: val_loss did not improve from 14.86042
# Epoch 4/100
# 291/291 [==============================] - 0s 445us/step - loss: 21.2966 - mean_absolute_error: 21.2966 - val_loss: 14.7509 - val_mean_absolute_error: 14.7509
#
# ...

# %%
r2_score(Y_test,predictions)
# Out:
# -0.6210201501132913

# %%
                                                                                  ''' On Adding one more hidden layer'''
  
NN_model = Sequential()
# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = X_train.shape[1], activation='relu'))
# The Hidden Layers :
NN_model.add(Dense(300, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(300, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(300, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(300, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(300, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(300, kernel_initializer='normal',activation='relu'))
# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))
# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
#NN_model.summary()
checkpoint_name = 'Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]
NN_model.fit(X_train, Y_train, epochs=100, batch_size=32, validation_split = 0.3,callbacks=callbacks_list) 
predictions = NN_model.predict(X_test)
# Out:
# Train on 291 samples, validate on 126 samples
# Epoch 1/100
# 291/291 [==============================] - 2s 7ms/step - loss: 23.4221 - mean_absolute_error: 23.4221 - val_loss: 14.9955 - val_mean_absolute_error: 14.9955
#
# Epoch 00001: val_loss improved from inf to 14.99546, saving model to Weights-001--14.99546.hdf5
# Epoch 2/100
# 291/291 [==============================] - 0s 561us/step - loss: 21.7459 - mean_absolute_error: 21.7459 - val_loss: 14.9115 - val_mean_absolute_error: 14.9115
#
# Epoch 00002: val_loss improved from 14.99546 to 14.91152, saving model to Weights-002--14.91152.hdf5
# Epoch 3/100
# 291/291 [==============================] - 0s 573us/step - loss: 22.7921 - mean_absolute_error: 22.7921 - val_loss: 21.9819 - val_mean_absolute_error: 21.9819
#
# Epoch 00003: val_loss did not improve from 14.91152
# Epoch 4/100
# ...

# %%
r2_score(Y_test,predictions)
# Out:
# -0.4918249270130606

# %%
                                                                                  ''' On Adding one more hidden layer'''
  
NN_model = Sequential()
# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = X_train.shape[1], activation='relu'))
# The Hidden Layers :
NN_model.add(Dense(300, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(300, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(300, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(300, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(300, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(300, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(300, kernel_initializer='normal',activation='relu'))
# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))
# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
#NN_model.summary()
checkpoint_name = 'Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]
NN_model.fit(X_train, Y_train, epochs=100, batch_size=32, validation_split = 0.3,callbacks=callbacks_list) 
predictions = NN_model.predict(X_test)
# Out:
# Train on 291 samples, validate on 126 samples
# Epoch 1/100
# 291/291 [==============================] - 2s 7ms/step - loss: 24.9315 - mean_absolute_error: 24.9315 - val_loss: 15.0322 - val_mean_absolute_error: 15.0322
#
# Epoch 00001: val_loss improved from inf to 15.03216, saving model to Weights-001--15.03216.hdf5
# Epoch 2/100
# 291/291 [==============================] - 0s 573us/step - loss: 21.7362 - mean_absolute_error: 21.7362 - val_loss: 14.9492 - val_mean_absolute_error: 14.9492
#
# Epoch 00002: val_loss improved from 15.03216 to 14.94920, saving model to Weights-002--14.94920.hdf5
# Epoch 3/100
# 291/291 [==============================] - 0s 584us/step - loss: 21.5615 - mean_absolute_error: 21.5615 - val_loss: 15.1541 - val_mean_absolute_error: 15.1541
#
# Epoch 00003: val_loss did not improve from 14.94920
# Epoch 4/100
# ...

# %%
r2_score(Y_test,predictions)
# Out:
# -0.7459379291697363

# %%
                                                                                  ''' One hidden layer'''
  
NN_model = Sequential()
# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = X_train.shape[1], activation='relu'))
# The Hidden Layers :
NN_model.add(Dense(300, kernel_initializer='normal',activation='relu'))
#output layer
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))
# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
#NN_model.summary()
checkpoint_name = 'Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]
NN_model.fit(X_train, Y_train, epochs=100, batch_size=32, validation_split = 0.3,callbacks=callbacks_list) 
predictions = NN_model.predict(X_test)
# Out:
# Train on 291 samples, validate on 126 samples
# Epoch 1/100
# 291/291 [==============================] - 2s 6ms/step - loss: 31.4364 - mean_absolute_error: 31.4364 - val_loss: 15.3073 - val_mean_absolute_error: 15.3073
#
# Epoch 00001: val_loss improved from inf to 15.30734, saving model to Weights-001--15.30734.hdf5
# Epoch 2/100
# 291/291 [==============================] - 0s 138us/step - loss: 23.3154 - mean_absolute_error: 23.3154 - val_loss: 18.2932 - val_mean_absolute_error: 18.2932
#
# Epoch 00002: val_loss did not improve from 15.30734
# Epoch 3/100
# 291/291 [==============================] - 0s 151us/step - loss: 22.1181 - mean_absolute_error: 22.1181 - val_loss: 15.0040 - val_mean_absolute_error: 15.0040
#
# Epoch 00003: val_loss improved from 15.30734 to 15.00399, saving model to Weights-003--15.00399.hdf5
# Epoch 4/100
# ...

# %%
r2_score(Y_test,predictions)
# Out:
# -0.48796932416444605

# %%
                                                                                  ''' On changing the activation funciton to sigmoid'''
  
NN_model = Sequential()
# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = X_train.shape[1], activation='sigmoid'))
# The Hidden Layers :
NN_model.add(Dense(300, kernel_initializer='normal',activation='sigmoid'))
NN_model.add(Dense(300, kernel_initializer='normal',activation='sigmoid'))
NN_model.add(Dense(300, kernel_initializer='normal',activation='sigmoid'))
NN_model.add(Dense(300, kernel_initializer='normal',activation='sigmoid'))
NN_model.add(Dense(300, kernel_initializer='normal',activation='sigmoid'))
NN_model.add(Dense(300, kernel_initializer='normal',activation='sigmoid'))
# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))
# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
#NN_model.summary()
checkpoint_name = 'Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]
NN_model.fit(X_train, Y_train, epochs=100, batch_size=32, validation_split = 0.3,callbacks=callbacks_list) 
predictions = NN_model.predict(X_test)
# Out:
# Train on 291 samples, validate on 126 samples
# Epoch 1/100
# 291/291 [==============================] - 2s 8ms/step - loss: 31.0075 - mean_absolute_error: 31.0075 - val_loss: 17.3944 - val_mean_absolute_error: 17.3944
#
# Epoch 00001: val_loss improved from inf to 17.39440, saving model to Weights-001--17.39440.hdf5
# Epoch 2/100
# 291/291 [==============================] - 0s 542us/step - loss: 27.2789 - mean_absolute_error: 27.2789 - val_loss: 15.5627 - val_mean_absolute_error: 15.5627
#
# Epoch 00002: val_loss improved from 17.39440 to 15.56275, saving model to Weights-002--15.56275.hdf5
# Epoch 3/100
# 291/291 [==============================] - 0s 552us/step - loss: 25.6677 - mean_absolute_error: 25.6677 - val_loss: 14.4215 - val_mean_absolute_error: 14.4215
#
# Epoch 00003: val_loss improved from 15.56275 to 14.42146, saving model to Weights-003--14.42146.hdf5
# Epoch 4/100
# ...

# %%
r2_score(Y_test,predictions)
# Out:
# -0.045314448932612494

# %%
                                                                                  ''' On changing the activation funciton to tanh'''
  
NN_model = Sequential()
# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = X_train.shape[1], activation='tanh'))
# The Hidden Layers :
NN_model.add(Dense(300, kernel_initializer='normal',activation='tanh'))
NN_model.add(Dense(300, kernel_initializer='normal',activation='tanh'))
NN_model.add(Dense(300, kernel_initializer='normal',activation='tanh'))
NN_model.add(Dense(300, kernel_initializer='normal',activation='tanh'))
NN_model.add(Dense(300, kernel_initializer='normal',activation='tanh'))
NN_model.add(Dense(300, kernel_initializer='normal',activation='tanh'))
# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))
# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
#NN_model.summary()
checkpoint_name = 'Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]
NN_model.fit(X_train, Y_train, epochs=100, batch_size=32, validation_split = 0.3,callbacks=callbacks_list) 
predictions = NN_model.predict(X_test)
# Out:
# Train on 291 samples, validate on 126 samples
# Epoch 1/100
# 291/291 [==============================] - 3s 9ms/step - loss: 27.5323 - mean_absolute_error: 27.5323 - val_loss: 13.4177 - val_mean_absolute_error: 13.4177
#
# Epoch 00001: val_loss improved from inf to 13.41771, saving model to Weights-001--13.41771.hdf5
# Epoch 2/100
# 291/291 [==============================] - 0s 581us/step - loss: 23.1486 - mean_absolute_error: 23.1486 - val_loss: 12.3381 - val_mean_absolute_error: 12.3381
#
# Epoch 00002: val_loss improved from 13.41771 to 12.33808, saving model to Weights-002--12.33808.hdf5
# Epoch 3/100
# 291/291 [==============================] - 0s 569us/step - loss: 22.1358 - mean_absolute_error: 22.1358 - val_loss: 12.0244 - val_mean_absolute_error: 12.0244
#
# Epoch 00003: val_loss improved from 12.33808 to 12.02439, saving model to Weights-003--12.02439.hdf5
# Epoch 4/100
# ...

# %%
r2_score(Y_test,predictions)
# Out:
# -0.026496695673462467

# %%
                                                                                  ''' On changing the number of neurons to 250'''
  
NN_model = Sequential()
# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = X_train.shape[1], activation='tanh'))
# The Hidden Layers :
NN_model.add(Dense(250, kernel_initializer='normal',activation='tanh'))
NN_model.add(Dense(250, kernel_initializer='normal',activation='tanh'))
NN_model.add(Dense(250, kernel_initializer='normal',activation='tanh'))
NN_model.add(Dense(250, kernel_initializer='normal',activation='tanh'))
NN_model.add(Dense(250, kernel_initializer='normal',activation='tanh'))
NN_model.add(Dense(250, kernel_initializer='normal',activation='tanh'))
# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))
# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
#NN_model.summary()
checkpoint_name = 'Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]
NN_model.fit(X_train, Y_train, epochs=100, batch_size=32, validation_split = 0.3,callbacks=callbacks_list) 
predictions = NN_model.predict(X_test)
# Out:
# Train on 291 samples, validate on 126 samples
# Epoch 1/100
# 291/291 [==============================] - 3s 9ms/step - loss: 29.2486 - mean_absolute_error: 29.2486 - val_loss: 14.9181 - val_mean_absolute_error: 14.9181
#
# Epoch 00001: val_loss improved from inf to 14.91809, saving model to Weights-001--14.91809.hdf5
# Epoch 2/100
# 291/291 [==============================] - 0s 406us/step - loss: 24.8604 - mean_absolute_error: 24.8604 - val_loss: 13.5188 - val_mean_absolute_error: 13.5188
#
# Epoch 00002: val_loss improved from 14.91809 to 13.51878, saving model to Weights-002--13.51878.hdf5
# Epoch 3/100
# 291/291 [==============================] - 0s 424us/step - loss: 23.3634 - mean_absolute_error: 23.3634 - val_loss: 12.5594 - val_mean_absolute_error: 12.5594
#
# Epoch 00003: val_loss improved from 13.51878 to 12.55937, saving model to Weights-003--12.55937.hdf5
# Epoch 4/100
# ...

# %%
r2_score(Y_test,predictions)
# Out:
# -0.02517469506882164

# %%
                                                                                  ''' On changing the number of neurons to 270'''
  
NN_model = Sequential()
# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = X_train.shape[1], activation='tanh'))
# The Hidden Layers :
NN_model.add(Dense(270, kernel_initializer='normal',activation='tanh'))
NN_model.add(Dense(270, kernel_initializer='normal',activation='tanh'))
NN_model.add(Dense(270, kernel_initializer='normal',activation='tanh'))
NN_model.add(Dense(270, kernel_initializer='normal',activation='tanh'))
NN_model.add(Dense(270, kernel_initializer='normal',activation='tanh'))
NN_model.add(Dense(270, kernel_initializer='normal',activation='tanh'))
# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))
# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
#NN_model.summary()
checkpoint_name = 'Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]
NN_model.fit(X_train, Y_train, epochs=100, batch_size=32, validation_split = 0.3,callbacks=callbacks_list) 
predictions = NN_model.predict(X_test)
# Out:
# Train on 291 samples, validate on 126 samples
# Epoch 1/100
# 291/291 [==============================] - 3s 9ms/step - loss: 28.0062 - mean_absolute_error: 28.0062 - val_loss: 13.6202 - val_mean_absolute_error: 13.6202
#
# Epoch 00001: val_loss improved from inf to 13.62016, saving model to Weights-001--13.62016.hdf5
# Epoch 2/100
# 291/291 [==============================] - 0s 493us/step - loss: 23.2855 - mean_absolute_error: 23.2855 - val_loss: 12.4480 - val_mean_absolute_error: 12.4480
#
# Epoch 00002: val_loss improved from 13.62016 to 12.44802, saving model to Weights-002--12.44802.hdf5
# Epoch 3/100
# 291/291 [==============================] - 0s 518us/step - loss: 22.3225 - mean_absolute_error: 22.3225 - val_loss: 12.0355 - val_mean_absolute_error: 12.0355
#
# Epoch 00003: val_loss improved from 12.44802 to 12.03546, saving model to Weights-003--12.03546.hdf5
# Epoch 4/100
# ...

# %%
r2_score(Y_test,predictions)
# Out:
# -0.03817334681334161

# %%
                                                                                  ''' On changing the number of neurons to 350'''
  
NN_model = Sequential()
# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = X_train.shape[1], activation='tanh'))
# The Hidden Layers :
NN_model.add(Dense(350, kernel_initializer='normal',activation='tanh'))
NN_model.add(Dense(350, kernel_initializer='normal',activation='tanh'))
NN_model.add(Dense(350, kernel_initializer='normal',activation='tanh'))
NN_model.add(Dense(350, kernel_initializer='normal',activation='tanh'))
NN_model.add(Dense(350, kernel_initializer='normal',activation='tanh'))
NN_model.add(Dense(350, kernel_initializer='normal',activation='tanh'))
# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))
# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
#NN_model.summary()
checkpoint_name = 'Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]
NN_model.fit(X_train, Y_train, epochs=100, batch_size=32, validation_split = 0.3,callbacks=callbacks_list) 
predictions = NN_model.predict(X_test)
# Out:
# Train on 291 samples, validate on 126 samples
# Epoch 1/100
# 291/291 [==============================] - 3s 10ms/step - loss: 26.5494 - mean_absolute_error: 26.5494 - val_loss: 12.4429 - val_mean_absolute_error: 12.4429
#
# Epoch 00001: val_loss improved from inf to 12.44293, saving model to Weights-001--12.44293.hdf5
# Epoch 2/100
# 291/291 [==============================] - 0s 677us/step - loss: 22.1631 - mean_absolute_error: 22.1631 - val_loss: 12.0342 - val_mean_absolute_error: 12.0342
#
# Epoch 00002: val_loss improved from 12.44293 to 12.03419, saving model to Weights-002--12.03419.hdf5
# Epoch 3/100
# 291/291 [==============================] - 0s 682us/step - loss: 21.5601 - mean_absolute_error: 21.5601 - val_loss: 12.2279 - val_mean_absolute_error: 12.2279
#
# Epoch 00003: val_loss did not improve from 12.03419
# Epoch 4/100
# ...

# %%
r2_score(Y_test,predictions)
# Out:
# -0.0228434484931066

# %%
                                                                                  ''' On changing the number of neurons to 100'''
  
NN_model = Sequential()
# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = X_train.shape[1], activation='tanh'))
# The Hidden Layers :
NN_model.add(Dense(100, kernel_initializer='normal',activation='tanh'))
NN_model.add(Dense(100, kernel_initializer='normal',activation='tanh'))
NN_model.add(Dense(100, kernel_initializer='normal',activation='tanh'))
NN_model.add(Dense(100, kernel_initializer='normal',activation='tanh'))
NN_model.add(Dense(100, kernel_initializer='normal',activation='tanh'))
NN_model.add(Dense(100, kernel_initializer='normal',activation='tanh'))
# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))
# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
#NN_model.summary()
checkpoint_name = 'Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]
NN_model.fit(X_train, Y_train, epochs=100, batch_size=32, validation_split = 0.3,callbacks=callbacks_list) 
predictions = NN_model.predict(X_test)
# Out:
# Train on 291 samples, validate on 126 samples
# Epoch 1/100
# 291/291 [==============================] - 3s 11ms/step - loss: 32.9991 - mean_absolute_error: 32.9991 - val_loss: 20.0437 - val_mean_absolute_error: 20.0437
#
# Epoch 00001: val_loss improved from inf to 20.04374, saving model to Weights-001--20.04374.hdf5
# Epoch 2/100
# 291/291 [==============================] - 0s 177us/step - loss: 30.2599 - mean_absolute_error: 30.2599 - val_loss: 18.0690 - val_mean_absolute_error: 18.0690
#
# Epoch 00002: val_loss improved from 20.04374 to 18.06905, saving model to Weights-002--18.06905.hdf5
# Epoch 3/100
# 291/291 [==============================] - 0s 196us/step - loss: 28.5966 - mean_absolute_error: 28.5966 - val_loss: 17.2009 - val_mean_absolute_error: 17.2009
#
# Epoch 00003: val_loss improved from 18.06905 to 17.20094, saving model to Weights-003--17.20094.hdf5
# Epoch 4/100
# ...

# %%
r2_score(Y_test,predictions)
# Out:
# -0.0310766952224526

# %%
                                                                                  ''' On changing the kernel_initialization parameter'''
  
NN_model = Sequential()
# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='uniform',input_dim = X_train.shape[1], activation='tanh'))
# The Hidden Layers :
NN_model.add(Dense(350, kernel_initializer='uniform',activation='tanh'))
NN_model.add(Dense(350, kernel_initializer='uniform',activation='tanh'))
NN_model.add(Dense(350, kernel_initializer='uniform',activation='tanh'))
NN_model.add(Dense(350, kernel_initializer='uniform',activation='tanh'))
NN_model.add(Dense(350, kernel_initializer='uniform',activation='tanh'))
NN_model.add(Dense(350, kernel_initializer='uniform',activation='tanh')) 
# The Output Layer : 
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))
# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
#NN_model.summary()
checkpoint_name = 'Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]
NN_model.fit(X_train, Y_train, epochs=100, batch_size=32, validation_split = 0.3,callbacks=callbacks_list) 
predictions = NN_model.predict(X_test)
# Out:
# Train on 291 samples, validate on 126 samples
# Epoch 1/100
# 291/291 [==============================] - 4s 13ms/step - loss: 27.2860 - mean_absolute_error: 27.2860 - val_loss: 12.3280 - val_mean_absolute_error: 12.3280
#
# Epoch 00001: val_loss improved from inf to 12.32795, saving model to Weights-001--12.32795.hdf5
# Epoch 2/100
# 291/291 [==============================] - 0s 689us/step - loss: 22.1368 - mean_absolute_error: 22.1368 - val_loss: 12.0434 - val_mean_absolute_error: 12.0434
#
# Epoch 00002: val_loss improved from 12.32795 to 12.04344, saving model to Weights-002--12.04344.hdf5
# Epoch 3/100
# 291/291 [==============================] - 0s 697us/step - loss: 21.4953 - mean_absolute_error: 21.4953 - val_loss: 12.4045 - val_mean_absolute_error: 12.4045
#
# Epoch 00003: val_loss did not improve from 12.04344
# Epoch 4/100
# ...

# %%
r2_score(Y_test,predictions)
# Out:
# -0.03143240333043362

# %%
                                                                                  ''' On changing the kernel_initialization parameter'''
  
NN_model = Sequential()
# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='random_uniform',input_dim = X_train.shape[1], activation='tanh'))
# The Hidden Layers :
NN_model.add(Dense(350, kernel_initializer='random_uniform',activation='tanh'))
NN_model.add(Dense(350, kernel_initializer='random_uniform',activation='tanh'))
NN_model.add(Dense(350, kernel_initializer='random_uniform',activation='tanh'))
NN_model.add(Dense(350, kernel_initializer='random_uniform',activation='tanh'))
NN_model.add(Dense(350, kernel_initializer='random_uniform',activation='tanh'))
NN_model.add(Dense(350, kernel_initializer='random_uniform',activation='tanh')) 
# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))
# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
#NN_model.summary()
checkpoint_name = 'Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]
NN_model.fit(X_train, Y_train, epochs=100, batch_size=32, validation_split = 0.3,callbacks=callbacks_list) 
predictions = NN_model.predict(X_test)
# Out:
# Train on 291 samples, validate on 126 samples
# Epoch 1/100
# 291/291 [==============================] - 4s 14ms/step - loss: 27.3045 - mean_absolute_error: 27.3045 - val_loss: 12.2944 - val_mean_absolute_error: 12.2944
#
# Epoch 00001: val_loss improved from inf to 12.29437, saving model to Weights-001--12.29437.hdf5
# Epoch 2/100
# 291/291 [==============================] - 0s 704us/step - loss: 22.0030 - mean_absolute_error: 22.0030 - val_loss: 12.0985 - val_mean_absolute_error: 12.0985
#
# Epoch 00002: val_loss improved from 12.29437 to 12.09846, saving model to Weights-002--12.09846.hdf5
# Epoch 3/100
# 291/291 [==============================] - 0s 707us/step - loss: 21.3975 - mean_absolute_error: 21.3975 - val_loss: 12.6448 - val_mean_absolute_error: 12.6448
#
# Epoch 00003: val_loss did not improve from 12.09846
# Epoch 4/100
# ...

# %%
r2_score(Y_test,predictions)
# Out:
# -0.024827191802177406

# %%
                                                                                  ''' On changing the epochs'''
  
NN_model = Sequential()
# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='random_uniform',input_dim = X_train.shape[1], activation='tanh'))
# The Hidden Layers :
NN_model.add(Dense(350, kernel_initializer='random_uniform',activation='tanh'))
NN_model.add(Dense(350, kernel_initializer='random_uniform',activation='tanh'))
NN_model.add(Dense(350, kernel_initializer='random_uniform',activation='tanh'))
NN_model.add(Dense(350, kernel_initializer='random_uniform',activation='tanh'))
NN_model.add(Dense(350, kernel_initializer='random_uniform',activation='tanh'))
NN_model.add(Dense(350, kernel_initializer='random_uniform',activation='tanh')) 
# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))
# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
#NN_model.summary()
checkpoint_name = 'Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]
NN_model.fit(X_train, Y_train, epochs=150, batch_size=32, validation_split = 0.3,callbacks=callbacks_list) 
predictions = NN_model.predict(X_test)
# Out:
# Train on 291 samples, validate on 126 samples
# Epoch 1/150
# 291/291 [==============================] - 4s 14ms/step - loss: 27.5487 - mean_absolute_error: 27.5487 - val_loss: 12.2335 - val_mean_absolute_error: 12.2335
#
# Epoch 00001: val_loss improved from inf to 12.23348, saving model to Weights-001--12.23348.hdf5
# Epoch 2/150
# 291/291 [==============================] - 0s 701us/step - loss: 21.8694 - mean_absolute_error: 21.8694 - val_loss: 12.1125 - val_mean_absolute_error: 12.1125
#
# Epoch 00002: val_loss improved from 12.23348 to 12.11249, saving model to Weights-002--12.11249.hdf5
# Epoch 3/150
# 291/291 [==============================] - 0s 737us/step - loss: 21.4128 - mean_absolute_error: 21.4128 - val_loss: 12.6582 - val_mean_absolute_error: 12.6582
#
# Epoch 00003: val_loss did not improve from 12.11249
# Epoch 4/150
# ...

# %%
r2_score(Y_test,predictions)
# Out:
# -0.02029073550564786

# %%
                                                                                  ''' On changing the epochs to 50'''
  
NN_model = Sequential()
# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='random_uniform',input_dim = X_train.shape[1], activation='tanh'))
# The Hidden Layers :
NN_model.add(Dense(50, kernel_initializer='random_uniform',activation='tanh'))
NN_model.add(Dense(50, kernel_initializer='random_uniform',activation='tanh'))
NN_model.add(Dense(50, kernel_initializer='random_uniform',activation='tanh'))
NN_model.add(Dense(50, kernel_initializer='random_uniform',activation='tanh'))
NN_model.add(Dense(50, kernel_initializer='random_uniform',activation='tanh'))
NN_model.add(Dense(50, kernel_initializer='random_uniform',activation='tanh')) 
# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))
# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
#NN_model.summary()
checkpoint_name = 'Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]
NN_model.fit(X_train, Y_train, epochs=50, batch_size=32, validation_split = 0.3,callbacks=callbacks_list) 
predictions = NN_model.predict(X_test)
# Out:
# Train on 291 samples, validate on 126 samples
# Epoch 1/50
# 291/291 [==============================] - 4s 14ms/step - loss: 33.4899 - mean_absolute_error: 33.4899 - val_loss: 21.9979 - val_mean_absolute_error: 21.9979
#
# Epoch 00001: val_loss improved from inf to 21.99792, saving model to Weights-001--21.99792.hdf5
# Epoch 2/50
# 291/291 [==============================] - 0s 176us/step - loss: 33.1117 - mean_absolute_error: 33.1117 - val_loss: 20.8704 - val_mean_absolute_error: 20.8704
#
# Epoch 00002: val_loss improved from 21.99792 to 20.87042, saving model to Weights-002--20.87042.hdf5
# Epoch 3/50
# 291/291 [==============================] - 0s 173us/step - loss: 31.6190 - mean_absolute_error: 31.6190 - val_loss: 19.5511 - val_mean_absolute_error: 19.5511
#
# Epoch 00003: val_loss improved from 20.87042 to 19.55106, saving model to Weights-003--19.55106.hdf5
# Epoch 4/50
# ...

# %%
r2_score(Y_test,predictions)
# Out:
# -0.07999560560834773
