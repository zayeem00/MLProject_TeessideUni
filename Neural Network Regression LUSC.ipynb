# %% [markdown]
# <a href="https://colab.research.google.com/github/zayeem00/MLProject_TeessideUni/blob/master/Neural%20Network%20Regression%20LUSC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error 
from matplotlib import pyplot as plt
import seaborn as sb
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)
from xgboost import XGBRegressor
# Out:
# Using TensorFlow backend.

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-19e19e7c-5d80-4ffd-b145-c5539f1f4c50" name="files[]" multiple disabled />
#      <output id="result-19e19e7c-5d80-4ffd-b145-c5539f1f4c50">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving LUSC.xlsx to LUSC (2).xlsx
# Saving survival_LUSC.xlsx to survival_LUSC (1).xlsx

# %%
import pandas as pd
tar=pd.read_excel('survival_LUSC (1).xlsx')
dt=pd.read_excel('LUSC (2).xlsx',index_col=0)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(dt,tar,test_size=0.3)
print(X_train.shape,Y_train.shape)
print(X_test.shape,Y_test.shape)
# Out:
# (350, 2794) (350, 1)
# (151, 2794) (151, 1)

# %%
NN_model = Sequential()

# The Input Layer :
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = X_train.shape[1], activation='relu'))

# The Hidden Layers :
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 128)               357760
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 522,625
# Trainable params: 522,625
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpoint_name = 'Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]

# %%
NN_model.fit(X_train, Y_train, epochs=100, batch_size=32, validation_split = 0.2,callbacks=callbacks_list)
# Out:
# Train on 280 samples, validate on 70 samples
# Epoch 1/100
# 280/280 [==============================] - 0s 572us/step - loss: 7.9493 - mean_absolute_error: 7.9493 - val_loss: 17.2020 - val_mean_absolute_error: 17.2020
#
# Epoch 00001: val_loss did not improve from 12.50318
# Epoch 2/100
# 280/280 [==============================] - 0s 511us/step - loss: 5.8842 - mean_absolute_error: 5.8842 - val_loss: 16.6407 - val_mean_absolute_error: 16.6407
#
# Epoch 00002: val_loss did not improve from 12.50318
# Epoch 3/100
# 280/280 [==============================] - 0s 507us/step - loss: 4.5836 - mean_absolute_error: 4.5836 - val_loss: 17.0966 - val_mean_absolute_error: 17.0966
#
# Epoch 00003: val_loss did not improve from 12.50318
# Epoch 4/100
# 280/280 [==============================] - 0s 531us/step - loss: 2.9485 - mean_absolute_error: 2.9485 - val_loss: 16.9590 - val_mean_absolute_error: 16.9590
#
# Epoch 00004: val_loss did not improve from 12.50318
# Epoch 5/100
# 280/280 [==============================] - 0s 538us/step - loss: 2.9090 - mean_absolute_error: 2.9090 - val_loss: 16.5111 - val_mean_absolute_error: 16.5111
#
# Epoch 00005: val_loss did not improve from 12.50318
# Epoch 6/100
# 280/280 [==============================] - 0s 562us/step - loss: 1.9524 - mean_absolute_error: 1.9524 - val_loss: 16.3017 - val_mean_absolute_error: 16.3017
#
# Epoch 00006: val_loss did not improve from 12.50318
# Epoch 7/100
# 280/280 [==============================] - 0s 511us/step - loss: 1.9921 - mean_absolute_error: 1.9921 - val_loss: 16.3273 - val_mean_absolute_error: 16.3273
#
# Epoch 00007: val_loss did not improve from 12.50318
# Epoch 8/100
# 280/280 [==============================] - 0s 510us/step - loss: 1.3236 - mean_absolute_error: 1.3236 - val_loss: 16.2712 - val_mean_absolute_error: 16.2712
#
# Epoch 00008: val_loss did not improve from 12.50318
# Epoch 9/100
# 280/280 [==============================] - 0s 518us/step - loss: 1.4763 - mean_absolute_error: 1.4763 - val_loss: 16.4468 - val_mean_absolute_error: 16.4468
#
# Epoch 00009: val_loss did not improve from 12.50318
# Epoch 10/100
# 280/280 [==============================] - 0s 528us/step - loss: 1.2340 - mean_absolute_error: 1.2340 - val_loss: 16.5692 - val_mean_absolute_error: 16.5692
#
# Epoch 00010: val_loss did not improve from 12.50318
# Epoch 11/100
# 280/280 [==============================] - 0s 526us/step - loss: 1.3853 - mean_absolute_error: 1.3853 - val_loss: 16.5757 - val_mean_absolute_error: 16.5757
#
# Epoch 00011: val_loss did not improve from 12.50318
# Epoch 12/100
# 280/280 [==============================] - 0s 472us/step - loss: 1.1474 - mean_absolute_error: 1.1474 - val_loss: 16.4365 - val_mean_absolute_error: 16.4365
#
# Epoch 00012: val_loss did not improve from 12.50318
# Epoch 13/100
# 280/280 [==============================] - 0s 486us/step - loss: 1.2752 - mean_absolute_error: 1.2752 - val_loss: 16.4885 - val_mean_absolute_error: 16.4885
#
# Epoch 00013: val_loss did not improve from 12.50318
# Epoch 14/100
# 280/280 [==============================] - 0s 562us/step - loss: 1.2515 - mean_absolute_error: 1.2515 - val_loss: 16.3939 - val_mean_absolute_error: 16.3939
#
# Epoch 00014: val_loss did not improve from 12.50318
# Epoch 15/100
# 280/280 [==============================] - 0s 505us/step - loss: 1.1566 - mean_absolute_error: 1.1566 - val_loss: 16.2156 - val_mean_absolute_error: 16.2156
#
# Epoch 00015: val_loss did not improve from 12.50318
# Epoch 16/100
# 280/280 [==============================] - 0s 500us/step - loss: 1.1651 - mean_absolute_error: 1.1651 - val_loss: 16.3482 - val_mean_absolute_error: 16.3482
#
# Epoch 00016: val_loss did not improve from 12.50318
# Epoch 17/100
# 280/280 [==============================] - 0s 542us/step - loss: 1.3247 - mean_absolute_error: 1.3247 - val_loss: 16.3650 - val_mean_absolute_error: 16.3650
#
# Epoch 00017: val_loss did not improve from 12.50318
# Epoch 18/100
# 280/280 [==============================] - 0s 511us/step - loss: 1.3111 - mean_absolute_error: 1.3111 - val_loss: 16.5059 - val_mean_absolute_error: 16.5059
#
# Epoch 00018: val_loss did not improve from 12.50318
# Epoch 19/100
# 280/280 [==============================] - 0s 525us/step - loss: 1.4161 - mean_absolute_error: 1.4161 - val_loss: 16.4040 - val_mean_absolute_error: 16.4040
#
# Epoch 00019: val_loss did not improve from 12.50318
# Epoch 20/100
# 280/280 [==============================] - 0s 523us/step - loss: 1.1806 - mean_absolute_error: 1.1806 - val_loss: 16.4060 - val_mean_absolute_error: 16.4060
#
# Epoch 00020: val_loss did not improve from 12.50318
# Epoch 21/100
# 280/280 [==============================] - 0s 550us/step - loss: 1.3335 - mean_absolute_error: 1.3335 - val_loss: 16.1656 - val_mean_absolute_error: 16.1656
#
# Epoch 00021: val_loss did not improve from 12.50318
# Epoch 22/100
# 280/280 [==============================] - 0s 517us/step - loss: 1.4429 - mean_absolute_error: 1.4429 - val_loss: 16.3495 - val_mean_absolute_error: 16.3495
#
# Epoch 00022: val_loss did not improve from 12.50318
# Epoch 23/100
# 280/280 [==============================] - 0s 538us/step - loss: 1.4150 - mean_absolute_error: 1.4150 - val_loss: 16.2505 - val_mean_absolute_error: 16.2505
#
# Epoch 00023: val_loss did not improve from 12.50318
# Epoch 24/100
# 280/280 [==============================] - 0s 514us/step - loss: 1.3710 - mean_absolute_error: 1.3710 - val_loss: 16.1409 - val_mean_absolute_error: 16.1409
#
# Epoch 00024: val_loss did not improve from 12.50318
# Epoch 25/100
# 280/280 [==============================] - 0s 511us/step - loss: 1.5304 - mean_absolute_error: 1.5304 - val_loss: 16.6421 - val_mean_absolute_error: 16.6421
#
# Epoch 00025: val_loss did not improve from 12.50318
# Epoch 26/100
# 280/280 [==============================] - 0s 515us/step - loss: 1.3692 - mean_absolute_error: 1.3692 - val_loss: 16.0936 - val_mean_absolute_error: 16.0936
#
# Epoch 00026: val_loss did not improve from 12.50318
# Epoch 27/100
# 280/280 [==============================] - 0s 525us/step - loss: 1.2479 - mean_absolute_error: 1.2479 - val_loss: 16.6388 - val_mean_absolute_error: 16.6388
#
# Epoch 00027: val_loss did not improve from 12.50318
# Epoch 28/100
# 280/280 [==============================] - 0s 513us/step - loss: 1.2340 - mean_absolute_error: 1.2340 - val_loss: 16.2407 - val_mean_absolute_error: 16.2407
#
# Epoch 00028: val_loss did not improve from 12.50318
# Epoch 29/100
# 280/280 [==============================] - 0s 538us/step - loss: 1.3257 - mean_absolute_error: 1.3257 - val_loss: 16.4881 - val_mean_absolute_error: 16.4881
#
# Epoch 00029: val_loss did not improve from 12.50318
# Epoch 30/100
# 280/280 [==============================] - 0s 516us/step - loss: 2.2136 - mean_absolute_error: 2.2136 - val_loss: 16.3062 - val_mean_absolute_error: 16.3062
#
# Epoch 00030: val_loss did not improve from 12.50318
# Epoch 31/100
# 280/280 [==============================] - 0s 515us/step - loss: 2.1505 - mean_absolute_error: 2.1505 - val_loss: 16.4783 - val_mean_absolute_error: 16.4783
#
# Epoch 00031: val_loss did not improve from 12.50318
# Epoch 32/100
# 280/280 [==============================] - 0s 503us/step - loss: 1.2049 - mean_absolute_error: 1.2049 - val_loss: 16.3332 - val_mean_absolute_error: 16.3332
#
# Epoch 00032: val_loss did not improve from 12.50318
# Epoch 33/100
# 280/280 [==============================] - 0s 512us/step - loss: 1.1870 - mean_absolute_error: 1.1870 - val_loss: 16.6147 - val_mean_absolute_error: 16.6147
#
# Epoch 00033: val_loss did not improve from 12.50318
# Epoch 34/100
# 280/280 [==============================] - 0s 510us/step - loss: 1.1127 - mean_absolute_error: 1.1127 - val_loss: 16.2383 - val_mean_absolute_error: 16.2383
#
# Epoch 00034: val_loss did not improve from 12.50318
# Epoch 35/100
# 280/280 [==============================] - 0s 523us/step - loss: 1.2208 - mean_absolute_error: 1.2208 - val_loss: 16.2476 - val_mean_absolute_error: 16.2476
#
# Epoch 00035: val_loss did not improve from 12.50318
# Epoch 36/100
# 280/280 [==============================] - 0s 516us/step - loss: 1.2837 - mean_absolute_error: 1.2837 - val_loss: 16.3902 - val_mean_absolute_error: 16.3902
#
# Epoch 00036: val_loss did not improve from 12.50318
# Epoch 37/100
# 280/280 [==============================] - 0s 515us/step - loss: 1.4396 - mean_absolute_error: 1.4396 - val_loss: 16.2661 - val_mean_absolute_error: 16.2661
#
# Epoch 00037: val_loss did not improve from 12.50318
# Epoch 38/100
# 280/280 [==============================] - 0s 527us/step - loss: 1.4522 - mean_absolute_error: 1.4522 - val_loss: 16.4472 - val_mean_absolute_error: 16.4472
#
# Epoch 00038: val_loss did not improve from 12.50318
# Epoch 39/100
# 280/280 [==============================] - 0s 506us/step - loss: 1.2633 - mean_absolute_error: 1.2633 - val_loss: 16.3228 - val_mean_absolute_error: 16.3228
#
# Epoch 00039: val_loss did not improve from 12.50318
# Epoch 40/100
# 280/280 [==============================] - 0s 526us/step - loss: 1.0763 - mean_absolute_error: 1.0763 - val_loss: 16.6027 - val_mean_absolute_error: 16.6027
#
# Epoch 00040: val_loss did not improve from 12.50318
# Epoch 41/100
# 280/280 [==============================] - 0s 529us/step - loss: 0.9716 - mean_absolute_error: 0.9716 - val_loss: 16.5771 - val_mean_absolute_error: 16.5771
#
# Epoch 00041: val_loss did not improve from 12.50318
# Epoch 42/100
# 280/280 [==============================] - 0s 529us/step - loss: 0.9938 - mean_absolute_error: 0.9938 - val_loss: 16.2693 - val_mean_absolute_error: 16.2693
#
# Epoch 00042: val_loss did not improve from 12.50318
# Epoch 43/100
# 280/280 [==============================] - 0s 531us/step - loss: 1.1830 - mean_absolute_error: 1.1830 - val_loss: 16.6979 - val_mean_absolute_error: 16.6979
#
# Epoch 00043: val_loss did not improve from 12.50318
# Epoch 44/100
# 280/280 [==============================] - 0s 518us/step - loss: 1.0483 - mean_absolute_error: 1.0483 - val_loss: 16.1495 - val_mean_absolute_error: 16.1495
#
# Epoch 00044: val_loss did not improve from 12.50318
# Epoch 45/100
# 280/280 [==============================] - 0s 535us/step - loss: 1.0892 - mean_absolute_error: 1.0892 - val_loss: 16.2648 - val_mean_absolute_error: 16.2648
#
# Epoch 00045: val_loss did not improve from 12.50318
# Epoch 46/100
# 280/280 [==============================] - 0s 533us/step - loss: 1.4585 - mean_absolute_error: 1.4585 - val_loss: 16.4378 - val_mean_absolute_error: 16.4378
#
# Epoch 00046: val_loss did not improve from 12.50318
# Epoch 47/100
# 280/280 [==============================] - 0s 530us/step - loss: 1.4454 - mean_absolute_error: 1.4454 - val_loss: 16.3854 - val_mean_absolute_error: 16.3854
#
# Epoch 00047: val_loss did not improve from 12.50318
# Epoch 48/100
# 280/280 [==============================] - 0s 551us/step - loss: 1.3425 - mean_absolute_error: 1.3425 - val_loss: 16.7551 - val_mean_absolute_error: 16.7551
#
# Epoch 00048: val_loss did not improve from 12.50318
# Epoch 49/100
# 280/280 [==============================] - 0s 516us/step - loss: 1.3288 - mean_absolute_error: 1.3288 - val_loss: 16.2580 - val_mean_absolute_error: 16.2580
#
# Epoch 00049: val_loss did not improve from 12.50318
# Epoch 50/100
# 280/280 [==============================] - 0s 513us/step - loss: 0.9484 - mean_absolute_error: 0.9484 - val_loss: 16.5281 - val_mean_absolute_error: 16.5281
#
# Epoch 00050: val_loss did not improve from 12.50318
# Epoch 51/100
# 280/280 [==============================] - 0s 510us/step - loss: 0.8835 - mean_absolute_error: 0.8835 - val_loss: 16.1955 - val_mean_absolute_error: 16.1955
#
# Epoch 00051: val_loss did not improve from 12.50318
# Epoch 52/100
# 280/280 [==============================] - 0s 518us/step - loss: 1.0658 - mean_absolute_error: 1.0658 - val_loss: 16.5832 - val_mean_absolute_error: 16.5832
#
# Epoch 00052: val_loss did not improve from 12.50318
# Epoch 53/100
# 280/280 [==============================] - 0s 523us/step - loss: 1.4551 - mean_absolute_error: 1.4551 - val_loss: 16.4426 - val_mean_absolute_error: 16.4426
#
# Epoch 00053: val_loss did not improve from 12.50318
# Epoch 54/100
# 280/280 [==============================] - 0s 543us/step - loss: 1.6398 - mean_absolute_error: 1.6398 - val_loss: 16.2534 - val_mean_absolute_error: 16.2534
#
# Epoch 00054: val_loss did not improve from 12.50318
# Epoch 55/100
# 280/280 [==============================] - 0s 528us/step - loss: 1.4363 - mean_absolute_error: 1.4363 - val_loss: 16.5055 - val_mean_absolute_error: 16.5055
#
# Epoch 00055: val_loss did not improve from 12.50318
# Epoch 56/100
# 280/280 [==============================] - 0s 517us/step - loss: 1.1120 - mean_absolute_error: 1.1120 - val_loss: 16.3030 - val_mean_absolute_error: 16.3030
#
# Epoch 00056: val_loss did not improve from 12.50318
# Epoch 57/100
# 280/280 [==============================] - 0s 548us/step - loss: 1.1079 - mean_absolute_error: 1.1079 - val_loss: 16.5803 - val_mean_absolute_error: 16.5803
#
# Epoch 00057: val_loss did not improve from 12.50318
# Epoch 58/100
# 280/280 [==============================] - 0s 526us/step - loss: 1.1095 - mean_absolute_error: 1.1095 - val_loss: 16.1612 - val_mean_absolute_error: 16.1612
#
# Epoch 00058: val_loss did not improve from 12.50318
# Epoch 59/100
# 280/280 [==============================] - 0s 507us/step - loss: 1.0999 - mean_absolute_error: 1.0999 - val_loss: 16.5169 - val_mean_absolute_error: 16.5169
#
# Epoch 00059: val_loss did not improve from 12.50318
# Epoch 60/100
# 280/280 [==============================] - 0s 527us/step - loss: 1.4401 - mean_absolute_error: 1.4401 - val_loss: 16.9956 - val_mean_absolute_error: 16.9956
#
# Epoch 00060: val_loss did not improve from 12.50318
# Epoch 61/100
# 280/280 [==============================] - 0s 540us/step - loss: 1.3869 - mean_absolute_error: 1.3869 - val_loss: 16.3856 - val_mean_absolute_error: 16.3856
#
# Epoch 00061: val_loss did not improve from 12.50318
# Epoch 62/100
# 280/280 [==============================] - 0s 510us/step - loss: 1.1801 - mean_absolute_error: 1.1801 - val_loss: 16.0689 - val_mean_absolute_error: 16.0689
#
# Epoch 00062: val_loss did not improve from 12.50318
# Epoch 63/100
# 280/280 [==============================] - 0s 514us/step - loss: 1.0929 - mean_absolute_error: 1.0929 - val_loss: 16.3278 - val_mean_absolute_error: 16.3278
#
# Epoch 00063: val_loss did not improve from 12.50318
# Epoch 64/100
# 280/280 [==============================] - 0s 527us/step - loss: 1.0325 - mean_absolute_error: 1.0325 - val_loss: 16.1359 - val_mean_absolute_error: 16.1359
#
# Epoch 00064: val_loss did not improve from 12.50318
# Epoch 65/100
# 280/280 [==============================] - 0s 534us/step - loss: 0.9562 - mean_absolute_error: 0.9562 - val_loss: 16.6784 - val_mean_absolute_error: 16.6784
#
# Epoch 00065: val_loss did not improve from 12.50318
# Epoch 66/100
# 280/280 [==============================] - 0s 528us/step - loss: 1.0155 - mean_absolute_error: 1.0155 - val_loss: 16.2697 - val_mean_absolute_error: 16.2697
#
# Epoch 00066: val_loss did not improve from 12.50318
# Epoch 67/100
# 280/280 [==============================] - 0s 540us/step - loss: 0.9028 - mean_absolute_error: 0.9028 - val_loss: 16.3085 - val_mean_absolute_error: 16.3085
#
# Epoch 00067: val_loss did not improve from 12.50318
# Epoch 68/100
# 280/280 [==============================] - 0s 551us/step - loss: 1.0178 - mean_absolute_error: 1.0178 - val_loss: 16.3398 - val_mean_absolute_error: 16.3398
#
# Epoch 00068: val_loss did not improve from 12.50318
# Epoch 69/100
# 280/280 [==============================] - 0s 536us/step - loss: 1.2557 - mean_absolute_error: 1.2557 - val_loss: 16.4213 - val_mean_absolute_error: 16.4213
#
# Epoch 00069: val_loss did not improve from 12.50318
# Epoch 70/100
# 280/280 [==============================] - 0s 517us/step - loss: 1.0481 - mean_absolute_error: 1.0481 - val_loss: 16.2185 - val_mean_absolute_error: 16.2185
#
# Epoch 00070: val_loss did not improve from 12.50318
# Epoch 71/100
# 280/280 [==============================] - 0s 527us/step - loss: 0.9901 - mean_absolute_error: 0.9901 - val_loss: 16.4358 - val_mean_absolute_error: 16.4358
#
# Epoch 00071: val_loss did not improve from 12.50318
# Epoch 72/100
# 280/280 [==============================] - 0s 528us/step - loss: 1.0390 - mean_absolute_error: 1.0390 - val_loss: 16.2078 - val_mean_absolute_error: 16.2078
#
# Epoch 00072: val_loss did not improve from 12.50318
# Epoch 73/100
# 280/280 [==============================] - 0s 527us/step - loss: 1.0523 - mean_absolute_error: 1.0523 - val_loss: 16.2723 - val_mean_absolute_error: 16.2723
#
# Epoch 00073: val_loss did not improve from 12.50318
# Epoch 74/100
# 280/280 [==============================] - 0s 520us/step - loss: 0.8645 - mean_absolute_error: 0.8645 - val_loss: 16.2241 - val_mean_absolute_error: 16.2241
#
# Epoch 00074: val_loss did not improve from 12.50318
# Epoch 75/100
# 280/280 [==============================] - 0s 515us/step - loss: 0.8103 - mean_absolute_error: 0.8103 - val_loss: 16.2439 - val_mean_absolute_error: 16.2439
#
# Epoch 00075: val_loss did not improve from 12.50318
# Epoch 76/100
# 280/280 [==============================] - 0s 528us/step - loss: 0.8631 - mean_absolute_error: 0.8631 - val_loss: 16.2970 - val_mean_absolute_error: 16.2970
#
# Epoch 00076: val_loss did not improve from 12.50318
# Epoch 77/100
# 280/280 [==============================] - 0s 531us/step - loss: 0.9020 - mean_absolute_error: 0.9020 - val_loss: 16.4634 - val_mean_absolute_error: 16.4634
#
# Epoch 00077: val_loss did not improve from 12.50318
# Epoch 78/100
# 280/280 [==============================] - 0s 521us/step - loss: 0.8958 - mean_absolute_error: 0.8958 - val_loss: 16.2477 - val_mean_absolute_error: 16.2477
#
# Epoch 00078: val_loss did not improve from 12.50318
# Epoch 79/100
# 280/280 [==============================] - 0s 532us/step - loss: 0.9338 - mean_absolute_error: 0.9338 - val_loss: 16.2440 - val_mean_absolute_error: 16.2440
#
# Epoch 00079: val_loss did not improve from 12.50318
# Epoch 80/100
# 280/280 [==============================] - 0s 567us/step - loss: 1.2141 - mean_absolute_error: 1.2141 - val_loss: 16.3073 - val_mean_absolute_error: 16.3073
#
# Epoch 00080: val_loss did not improve from 12.50318
# Epoch 81/100
# 280/280 [==============================] - 0s 558us/step - loss: 1.0635 - mean_absolute_error: 1.0635 - val_loss: 16.4280 - val_mean_absolute_error: 16.4280
#
# Epoch 00081: val_loss did not improve from 12.50318
# Epoch 82/100
# 280/280 [==============================] - 0s 549us/step - loss: 1.1155 - mean_absolute_error: 1.1155 - val_loss: 16.2450 - val_mean_absolute_error: 16.2450
#
# Epoch 00082: val_loss did not improve from 12.50318
# Epoch 83/100
# 280/280 [==============================] - 0s 526us/step - loss: 1.0873 - mean_absolute_error: 1.0873 - val_loss: 16.4220 - val_mean_absolute_error: 16.4220
#
# Epoch 00083: val_loss did not improve from 12.50318
# Epoch 84/100
# 280/280 [==============================] - 0s 555us/step - loss: 1.3320 - mean_absolute_error: 1.3320 - val_loss: 16.4720 - val_mean_absolute_error: 16.4720
#
# Epoch 00084: val_loss did not improve from 12.50318
# Epoch 85/100
# 280/280 [==============================] - 0s 546us/step - loss: 1.3107 - mean_absolute_error: 1.3107 - val_loss: 16.3934 - val_mean_absolute_error: 16.3934
#
# Epoch 00085: val_loss did not improve from 12.50318
# Epoch 86/100
# 280/280 [==============================] - 0s 515us/step - loss: 1.4620 - mean_absolute_error: 1.4620 - val_loss: 16.3218 - val_mean_absolute_error: 16.3218
#
# Epoch 00086: val_loss did not improve from 12.50318
# Epoch 87/100
# 280/280 [==============================] - 0s 517us/step - loss: 1.3227 - mean_absolute_error: 1.3227 - val_loss: 16.0447 - val_mean_absolute_error: 16.0447
#
# Epoch 00087: val_loss did not improve from 12.50318
# Epoch 88/100
# 280/280 [==============================] - 0s 513us/step - loss: 1.2693 - mean_absolute_error: 1.2693 - val_loss: 16.1812 - val_mean_absolute_error: 16.1812
#
# Epoch 00088: val_loss did not improve from 12.50318
# Epoch 89/100
# 280/280 [==============================] - 0s 523us/step - loss: 1.3348 - mean_absolute_error: 1.3348 - val_loss: 16.0894 - val_mean_absolute_error: 16.0894
#
# Epoch 00089: val_loss did not improve from 12.50318
# Epoch 90/100
# 280/280 [==============================] - 0s 526us/step - loss: 1.2483 - mean_absolute_error: 1.2483 - val_loss: 16.0181 - val_mean_absolute_error: 16.0181
#
# Epoch 00090: val_loss did not improve from 12.50318
# Epoch 91/100
# 280/280 [==============================] - 0s 512us/step - loss: 1.2090 - mean_absolute_error: 1.2090 - val_loss: 16.2815 - val_mean_absolute_error: 16.2815
#
# Epoch 00091: val_loss did not improve from 12.50318
# Epoch 92/100
# 280/280 [==============================] - 0s 514us/step - loss: 1.0305 - mean_absolute_error: 1.0305 - val_loss: 16.2896 - val_mean_absolute_error: 16.2896
#
# Epoch 00092: val_loss did not improve from 12.50318
# Epoch 93/100
# 280/280 [==============================] - 0s 521us/step - loss: 0.9762 - mean_absolute_error: 0.9762 - val_loss: 16.4043 - val_mean_absolute_error: 16.4043
#
# Epoch 00093: val_loss did not improve from 12.50318
# Epoch 94/100
# 280/280 [==============================] - 0s 525us/step - loss: 0.9309 - mean_absolute_error: 0.9309 - val_loss: 16.1992 - val_mean_absolute_error: 16.1992
#
# Epoch 00094: val_loss did not improve from 12.50318
# Epoch 95/100
# 280/280 [==============================] - 0s 539us/step - loss: 1.0364 - mean_absolute_error: 1.0364 - val_loss: 16.6883 - val_mean_absolute_error: 16.6883
#
# Epoch 00095: val_loss did not improve from 12.50318
# Epoch 96/100
# 280/280 [==============================] - 0s 671us/step - loss: 0.9859 - mean_absolute_error: 0.9859 - val_loss: 16.2189 - val_mean_absolute_error: 16.2189
#
# Epoch 00096: val_loss did not improve from 12.50318
# Epoch 97/100
# 280/280 [==============================] - 0s 531us/step - loss: 0.8860 - mean_absolute_error: 0.8860 - val_loss: 16.1809 - val_mean_absolute_error: 16.1809
#
# Epoch 00097: val_loss did not improve from 12.50318
# Epoch 98/100
# 280/280 [==============================] - 0s 608us/step - loss: 0.9555 - mean_absolute_error: 0.9555 - val_loss: 16.1231 - val_mean_absolute_error: 16.1231
#
# Epoch 00098: val_loss did not improve from 12.50318
# Epoch 99/100
# 280/280 [==============================] - 0s 549us/step - loss: 1.0050 - mean_absolute_error: 1.0050 - val_loss: 16.0897 - val_mean_absolute_error: 16.0897
#
# Epoch 00099: val_loss did not improve from 12.50318
# Epoch 100/100
# 280/280 [==============================] - 0s 584us/step - loss: 1.0399 - mean_absolute_error: 1.0399 - val_loss: 16.1277 - val_mean_absolute_error: 16.1277
#
# Epoch 00100: val_loss did not improve from 12.50318

# %%
predictions = NN_model.predict(X_train)
from sklearn.metrics import r2_score
accuracy=r2_score(Y_train,predictions)
print('train')
print(accuracy)
# Out:
# train
# 0.8546977042182765

# %%
NN_model.fit(X_test, Y_test, epochs=100, batch_size=32, validation_split = 0.3,callbacks=callbacks_list)
# Out:
# Train on 105 samples, validate on 46 samples
# Epoch 1/100
# 105/105 [==============================] - 0s 586us/step - loss: 7.6266 - mean_absolute_error: 7.6266 - val_loss: 14.7330 - val_mean_absolute_error: 14.7330
#
# Epoch 00001: val_loss did not improve from 12.50318
# Epoch 2/100
# 105/105 [==============================] - 0s 610us/step - loss: 5.3310 - mean_absolute_error: 5.3310 - val_loss: 13.1504 - val_mean_absolute_error: 13.1504
#
# Epoch 00002: val_loss did not improve from 12.50318
# Epoch 3/100
# 105/105 [==============================] - 0s 544us/step - loss: 4.3279 - mean_absolute_error: 4.3279 - val_loss: 13.7116 - val_mean_absolute_error: 13.7116
#
# Epoch 00003: val_loss did not improve from 12.50318
# Epoch 4/100
# 105/105 [==============================] - 0s 596us/step - loss: 3.8609 - mean_absolute_error: 3.8609 - val_loss: 13.8677 - val_mean_absolute_error: 13.8677
#
# Epoch 00004: val_loss did not improve from 12.50318
# Epoch 5/100
# 105/105 [==============================] - 0s 570us/step - loss: 3.1659 - mean_absolute_error: 3.1659 - val_loss: 13.6390 - val_mean_absolute_error: 13.6390
#
# Epoch 00005: val_loss did not improve from 12.50318
# Epoch 6/100
# 105/105 [==============================] - 0s 592us/step - loss: 1.8347 - mean_absolute_error: 1.8347 - val_loss: 13.9669 - val_mean_absolute_error: 13.9669
#
# Epoch 00006: val_loss did not improve from 12.50318
# Epoch 7/100
# 105/105 [==============================] - 0s 583us/step - loss: 1.7223 - mean_absolute_error: 1.7223 - val_loss: 14.0515 - val_mean_absolute_error: 14.0515
#
# Epoch 00007: val_loss did not improve from 12.50318
# Epoch 8/100
# 105/105 [==============================] - 0s 582us/step - loss: 1.6659 - mean_absolute_error: 1.6659 - val_loss: 13.8433 - val_mean_absolute_error: 13.8433
#
# Epoch 00008: val_loss did not improve from 12.50318
# Epoch 9/100
# 105/105 [==============================] - 0s 612us/step - loss: 1.7235 - mean_absolute_error: 1.7235 - val_loss: 14.5457 - val_mean_absolute_error: 14.5457
#
# Epoch 00009: val_loss did not improve from 12.50318
# Epoch 10/100
# 105/105 [==============================] - 0s 588us/step - loss: 2.5940 - mean_absolute_error: 2.5940 - val_loss: 13.7059 - val_mean_absolute_error: 13.7059
#
# Epoch 00010: val_loss did not improve from 12.50318
# Epoch 11/100
# 105/105 [==============================] - 0s 620us/step - loss: 2.6316 - mean_absolute_error: 2.6316 - val_loss: 14.1633 - val_mean_absolute_error: 14.1633
#
# Epoch 00011: val_loss did not improve from 12.50318
# Epoch 12/100
# 105/105 [==============================] - 0s 595us/step - loss: 1.8568 - mean_absolute_error: 1.8568 - val_loss: 13.9844 - val_mean_absolute_error: 13.9844
#
# Epoch 00012: val_loss did not improve from 12.50318
# Epoch 13/100
# 105/105 [==============================] - 0s 588us/step - loss: 1.4673 - mean_absolute_error: 1.4673 - val_loss: 14.0980 - val_mean_absolute_error: 14.0980
#
# Epoch 00013: val_loss did not improve from 12.50318
# Epoch 14/100
# 105/105 [==============================] - 0s 608us/step - loss: 1.1600 - mean_absolute_error: 1.1600 - val_loss: 14.0077 - val_mean_absolute_error: 14.0077
#
# Epoch 00014: val_loss did not improve from 12.50318
# Epoch 15/100
# 105/105 [==============================] - 0s 593us/step - loss: 1.2591 - mean_absolute_error: 1.2591 - val_loss: 14.0655 - val_mean_absolute_error: 14.0655
#
# Epoch 00015: val_loss did not improve from 12.50318
# Epoch 16/100
# 105/105 [==============================] - 0s 561us/step - loss: 1.2922 - mean_absolute_error: 1.2922 - val_loss: 13.8562 - val_mean_absolute_error: 13.8562
#
# Epoch 00016: val_loss did not improve from 12.50318
# Epoch 17/100
# 105/105 [==============================] - 0s 529us/step - loss: 1.2273 - mean_absolute_error: 1.2273 - val_loss: 14.1113 - val_mean_absolute_error: 14.1113
#
# Epoch 00017: val_loss did not improve from 12.50318
# Epoch 18/100
# 105/105 [==============================] - 0s 519us/step - loss: 1.3884 - mean_absolute_error: 1.3884 - val_loss: 13.9059 - val_mean_absolute_error: 13.9059
#
# Epoch 00018: val_loss did not improve from 12.50318
# Epoch 19/100
# 105/105 [==============================] - 0s 546us/step - loss: 1.4325 - mean_absolute_error: 1.4325 - val_loss: 14.5841 - val_mean_absolute_error: 14.5841
#
# Epoch 00019: val_loss did not improve from 12.50318
# Epoch 20/100
# 105/105 [==============================] - 0s 542us/step - loss: 2.3154 - mean_absolute_error: 2.3154 - val_loss: 14.0725 - val_mean_absolute_error: 14.0725
#
# Epoch 00020: val_loss did not improve from 12.50318
# Epoch 21/100
# 105/105 [==============================] - 0s 543us/step - loss: 3.0851 - mean_absolute_error: 3.0851 - val_loss: 14.3928 - val_mean_absolute_error: 14.3928
#
# Epoch 00021: val_loss did not improve from 12.50318
# Epoch 22/100
# 105/105 [==============================] - 0s 579us/step - loss: 2.0348 - mean_absolute_error: 2.0348 - val_loss: 14.3600 - val_mean_absolute_error: 14.3600
#
# Epoch 00022: val_loss did not improve from 12.50318
# Epoch 23/100
# 105/105 [==============================] - 0s 623us/step - loss: 2.0114 - mean_absolute_error: 2.0114 - val_loss: 14.2185 - val_mean_absolute_error: 14.2185
#
# Epoch 00023: val_loss did not improve from 12.50318
# Epoch 24/100
# 105/105 [==============================] - 0s 622us/step - loss: 1.5613 - mean_absolute_error: 1.5613 - val_loss: 14.1825 - val_mean_absolute_error: 14.1825
#
# Epoch 00024: val_loss did not improve from 12.50318
# Epoch 25/100
# 105/105 [==============================] - 0s 637us/step - loss: 1.5764 - mean_absolute_error: 1.5764 - val_loss: 14.2247 - val_mean_absolute_error: 14.2247
#
# Epoch 00025: val_loss did not improve from 12.50318
# Epoch 26/100
# 105/105 [==============================] - 0s 576us/step - loss: 1.2126 - mean_absolute_error: 1.2126 - val_loss: 14.2932 - val_mean_absolute_error: 14.2932
#
# Epoch 00026: val_loss did not improve from 12.50318
# Epoch 27/100
# 105/105 [==============================] - 0s 559us/step - loss: 1.1214 - mean_absolute_error: 1.1214 - val_loss: 14.1233 - val_mean_absolute_error: 14.1233
#
# Epoch 00027: val_loss did not improve from 12.50318
# Epoch 28/100
# 105/105 [==============================] - 0s 580us/step - loss: 1.0829 - mean_absolute_error: 1.0829 - val_loss: 14.3201 - val_mean_absolute_error: 14.3201
#
# Epoch 00028: val_loss did not improve from 12.50318
# Epoch 29/100
# 105/105 [==============================] - 0s 597us/step - loss: 1.2321 - mean_absolute_error: 1.2321 - val_loss: 14.1496 - val_mean_absolute_error: 14.1496
#
# Epoch 00029: val_loss did not improve from 12.50318
# Epoch 30/100
# 105/105 [==============================] - 0s 595us/step - loss: 1.4690 - mean_absolute_error: 1.4690 - val_loss: 15.0139 - val_mean_absolute_error: 15.0139
#
# Epoch 00030: val_loss did not improve from 12.50318
# Epoch 31/100
# 105/105 [==============================] - 0s 585us/step - loss: 1.8825 - mean_absolute_error: 1.8825 - val_loss: 14.1648 - val_mean_absolute_error: 14.1648
#
# Epoch 00031: val_loss did not improve from 12.50318
# Epoch 32/100
# 105/105 [==============================] - 0s 585us/step - loss: 2.0823 - mean_absolute_error: 2.0823 - val_loss: 14.9323 - val_mean_absolute_error: 14.9323
#
# Epoch 00032: val_loss did not improve from 12.50318
# Epoch 33/100
# 105/105 [==============================] - 0s 572us/step - loss: 1.7421 - mean_absolute_error: 1.7421 - val_loss: 14.6803 - val_mean_absolute_error: 14.6803
#
# Epoch 00033: val_loss did not improve from 12.50318
# Epoch 34/100
# 105/105 [==============================] - 0s 593us/step - loss: 1.7471 - mean_absolute_error: 1.7471 - val_loss: 15.0379 - val_mean_absolute_error: 15.0379
#
# Epoch 00034: val_loss did not improve from 12.50318
# Epoch 35/100
# 105/105 [==============================] - 0s 645us/step - loss: 1.7489 - mean_absolute_error: 1.7489 - val_loss: 14.6055 - val_mean_absolute_error: 14.6055
#
# Epoch 00035: val_loss did not improve from 12.50318
# Epoch 36/100
# 105/105 [==============================] - 0s 604us/step - loss: 1.8481 - mean_absolute_error: 1.8481 - val_loss: 14.5281 - val_mean_absolute_error: 14.5281
#
# Epoch 00036: val_loss did not improve from 12.50318
# Epoch 37/100
# 105/105 [==============================] - 0s 588us/step - loss: 1.8714 - mean_absolute_error: 1.8714 - val_loss: 14.3425 - val_mean_absolute_error: 14.3425
#
# Epoch 00037: val_loss did not improve from 12.50318
# Epoch 38/100
# 105/105 [==============================] - 0s 645us/step - loss: 1.4871 - mean_absolute_error: 1.4871 - val_loss: 14.6768 - val_mean_absolute_error: 14.6768
#
# Epoch 00038: val_loss did not improve from 12.50318
# Epoch 39/100
# 105/105 [==============================] - 0s 620us/step - loss: 1.5060 - mean_absolute_error: 1.5060 - val_loss: 14.5933 - val_mean_absolute_error: 14.5933
#
# Epoch 00039: val_loss did not improve from 12.50318
# Epoch 40/100
# 105/105 [==============================] - 0s 632us/step - loss: 1.4262 - mean_absolute_error: 1.4262 - val_loss: 14.4166 - val_mean_absolute_error: 14.4166
#
# Epoch 00040: val_loss did not improve from 12.50318
# Epoch 41/100
# 105/105 [==============================] - 0s 567us/step - loss: 1.3511 - mean_absolute_error: 1.3511 - val_loss: 14.3164 - val_mean_absolute_error: 14.3164
#
# Epoch 00041: val_loss did not improve from 12.50318
# Epoch 42/100
# 105/105 [==============================] - 0s 581us/step - loss: 1.4107 - mean_absolute_error: 1.4107 - val_loss: 14.2162 - val_mean_absolute_error: 14.2162
#
# Epoch 00042: val_loss did not improve from 12.50318
# Epoch 43/100
# 105/105 [==============================] - 0s 642us/step - loss: 1.3639 - mean_absolute_error: 1.3639 - val_loss: 14.3069 - val_mean_absolute_error: 14.3069
#
# Epoch 00043: val_loss did not improve from 12.50318
# Epoch 44/100
# 105/105 [==============================] - 0s 601us/step - loss: 1.4397 - mean_absolute_error: 1.4397 - val_loss: 14.1804 - val_mean_absolute_error: 14.1804
#
# Epoch 00044: val_loss did not improve from 12.50318
# Epoch 45/100
# 105/105 [==============================] - 0s 581us/step - loss: 2.3834 - mean_absolute_error: 2.3834 - val_loss: 14.6839 - val_mean_absolute_error: 14.6839
#
# Epoch 00045: val_loss did not improve from 12.50318
# Epoch 46/100
# 105/105 [==============================] - 0s 583us/step - loss: 2.4065 - mean_absolute_error: 2.4065 - val_loss: 14.6482 - val_mean_absolute_error: 14.6482
#
# Epoch 00046: val_loss did not improve from 12.50318
# Epoch 47/100
# 105/105 [==============================] - 0s 585us/step - loss: 1.8392 - mean_absolute_error: 1.8392 - val_loss: 14.1956 - val_mean_absolute_error: 14.1956
#
# Epoch 00047: val_loss did not improve from 12.50318
# Epoch 48/100
# 105/105 [==============================] - 0s 565us/step - loss: 1.5071 - mean_absolute_error: 1.5071 - val_loss: 14.6026 - val_mean_absolute_error: 14.6026
#
# Epoch 00048: val_loss did not improve from 12.50318
# Epoch 49/100
# 105/105 [==============================] - 0s 557us/step - loss: 1.9355 - mean_absolute_error: 1.9355 - val_loss: 14.3747 - val_mean_absolute_error: 14.3747
#
# Epoch 00049: val_loss did not improve from 12.50318
# Epoch 50/100
# 105/105 [==============================] - 0s 615us/step - loss: 2.0002 - mean_absolute_error: 2.0002 - val_loss: 14.8254 - val_mean_absolute_error: 14.8254
#
# Epoch 00050: val_loss did not improve from 12.50318
# Epoch 51/100
# 105/105 [==============================] - 0s 601us/step - loss: 1.6573 - mean_absolute_error: 1.6573 - val_loss: 14.5303 - val_mean_absolute_error: 14.5303
#
# Epoch 00051: val_loss did not improve from 12.50318
# Epoch 52/100
# 105/105 [==============================] - 0s 647us/step - loss: 1.3113 - mean_absolute_error: 1.3113 - val_loss: 14.9987 - val_mean_absolute_error: 14.9987
#
# Epoch 00052: val_loss did not improve from 12.50318
# Epoch 53/100
# 105/105 [==============================] - 0s 675us/step - loss: 1.5456 - mean_absolute_error: 1.5456 - val_loss: 14.6029 - val_mean_absolute_error: 14.6029
#
# Epoch 00053: val_loss did not improve from 12.50318
# Epoch 54/100
# 105/105 [==============================] - 0s 610us/step - loss: 1.6496 - mean_absolute_error: 1.6496 - val_loss: 14.9784 - val_mean_absolute_error: 14.9784
#
# Epoch 00054: val_loss did not improve from 12.50318
# Epoch 55/100
# 105/105 [==============================] - 0s 582us/step - loss: 1.7046 - mean_absolute_error: 1.7046 - val_loss: 14.7253 - val_mean_absolute_error: 14.7253
#
# Epoch 00055: val_loss did not improve from 12.50318
# Epoch 56/100
# 105/105 [==============================] - 0s 567us/step - loss: 1.3086 - mean_absolute_error: 1.3086 - val_loss: 14.8469 - val_mean_absolute_error: 14.8469
#
# Epoch 00056: val_loss did not improve from 12.50318
# Epoch 57/100
# 105/105 [==============================] - 0s 591us/step - loss: 1.3216 - mean_absolute_error: 1.3216 - val_loss: 14.6200 - val_mean_absolute_error: 14.6200
#
# Epoch 00057: val_loss did not improve from 12.50318
# Epoch 58/100
# 105/105 [==============================] - 0s 583us/step - loss: 1.4960 - mean_absolute_error: 1.4960 - val_loss: 14.6709 - val_mean_absolute_error: 14.6709
#
# Epoch 00058: val_loss did not improve from 12.50318
# Epoch 59/100
# 105/105 [==============================] - 0s 570us/step - loss: 1.1914 - mean_absolute_error: 1.1914 - val_loss: 14.2948 - val_mean_absolute_error: 14.2948
#
# Epoch 00059: val_loss did not improve from 12.50318
# Epoch 60/100
# 105/105 [==============================] - 0s 599us/step - loss: 1.7849 - mean_absolute_error: 1.7849 - val_loss: 14.4488 - val_mean_absolute_error: 14.4488
#
# Epoch 00060: val_loss did not improve from 12.50318
# Epoch 61/100
# 105/105 [==============================] - 0s 593us/step - loss: 1.2992 - mean_absolute_error: 1.2992 - val_loss: 14.3388 - val_mean_absolute_error: 14.3388
#
# Epoch 00061: val_loss did not improve from 12.50318
# Epoch 62/100
# 105/105 [==============================] - 0s 589us/step - loss: 1.1250 - mean_absolute_error: 1.1250 - val_loss: 14.3210 - val_mean_absolute_error: 14.3210
#
# Epoch 00062: val_loss did not improve from 12.50318
# Epoch 63/100
# 105/105 [==============================] - 0s 573us/step - loss: 1.3033 - mean_absolute_error: 1.3033 - val_loss: 14.6452 - val_mean_absolute_error: 14.6452
#
# Epoch 00063: val_loss did not improve from 12.50318
# Epoch 64/100
# 105/105 [==============================] - 0s 672us/step - loss: 1.1657 - mean_absolute_error: 1.1657 - val_loss: 14.3175 - val_mean_absolute_error: 14.3175
#
# Epoch 00064: val_loss did not improve from 12.50318
# Epoch 65/100
# 105/105 [==============================] - 0s 635us/step - loss: 1.1790 - mean_absolute_error: 1.1790 - val_loss: 14.7525 - val_mean_absolute_error: 14.7525
#
# Epoch 00065: val_loss did not improve from 12.50318
# Epoch 66/100
# 105/105 [==============================] - 0s 662us/step - loss: 1.7698 - mean_absolute_error: 1.7698 - val_loss: 14.4275 - val_mean_absolute_error: 14.4275
#
# Epoch 00066: val_loss did not improve from 12.50318
# Epoch 67/100
# 105/105 [==============================] - 0s 599us/step - loss: 1.1861 - mean_absolute_error: 1.1861 - val_loss: 14.4633 - val_mean_absolute_error: 14.4633
#
# Epoch 00067: val_loss did not improve from 12.50318
# Epoch 68/100
# 105/105 [==============================] - 0s 610us/step - loss: 1.1664 - mean_absolute_error: 1.1664 - val_loss: 14.5581 - val_mean_absolute_error: 14.5581
#
# Epoch 00068: val_loss did not improve from 12.50318
# Epoch 69/100
# 105/105 [==============================] - 0s 579us/step - loss: 1.0268 - mean_absolute_error: 1.0268 - val_loss: 14.4769 - val_mean_absolute_error: 14.4769
#
# Epoch 00069: val_loss did not improve from 12.50318
# Epoch 70/100
# 105/105 [==============================] - 0s 622us/step - loss: 1.1649 - mean_absolute_error: 1.1649 - val_loss: 14.7561 - val_mean_absolute_error: 14.7561
#
# Epoch 00070: val_loss did not improve from 12.50318
# Epoch 71/100
# 105/105 [==============================] - 0s 610us/step - loss: 2.1421 - mean_absolute_error: 2.1421 - val_loss: 14.2494 - val_mean_absolute_error: 14.2494
#
# Epoch 00071: val_loss did not improve from 12.50318
# Epoch 72/100
# 105/105 [==============================] - 0s 613us/step - loss: 2.1385 - mean_absolute_error: 2.1385 - val_loss: 14.5239 - val_mean_absolute_error: 14.5239
#
# Epoch 00072: val_loss did not improve from 12.50318
# Epoch 73/100
# 105/105 [==============================] - 0s 576us/step - loss: 2.1999 - mean_absolute_error: 2.1999 - val_loss: 14.4017 - val_mean_absolute_error: 14.4017
#
# Epoch 00073: val_loss did not improve from 12.50318
# Epoch 74/100
# 105/105 [==============================] - 0s 585us/step - loss: 2.1829 - mean_absolute_error: 2.1829 - val_loss: 14.4539 - val_mean_absolute_error: 14.4539
#
# Epoch 00074: val_loss did not improve from 12.50318
# Epoch 75/100
# 105/105 [==============================] - 0s 603us/step - loss: 1.8976 - mean_absolute_error: 1.8976 - val_loss: 14.9835 - val_mean_absolute_error: 14.9835
#
# Epoch 00075: val_loss did not improve from 12.50318
# Epoch 76/100
# 105/105 [==============================] - 0s 632us/step - loss: 1.4817 - mean_absolute_error: 1.4817 - val_loss: 14.3717 - val_mean_absolute_error: 14.3717
#
# Epoch 00076: val_loss did not improve from 12.50318
# Epoch 77/100
# 105/105 [==============================] - 0s 625us/step - loss: 1.2977 - mean_absolute_error: 1.2977 - val_loss: 15.0079 - val_mean_absolute_error: 15.0079
#
# Epoch 00077: val_loss did not improve from 12.50318
# Epoch 78/100
# 105/105 [==============================] - 0s 621us/step - loss: 2.2795 - mean_absolute_error: 2.2795 - val_loss: 14.2919 - val_mean_absolute_error: 14.2919
#
# Epoch 00078: val_loss did not improve from 12.50318
# Epoch 79/100
# 105/105 [==============================] - 0s 631us/step - loss: 1.6926 - mean_absolute_error: 1.6926 - val_loss: 14.9458 - val_mean_absolute_error: 14.9458
#
# Epoch 00079: val_loss did not improve from 12.50318
# Epoch 80/100
# 105/105 [==============================] - 0s 651us/step - loss: 1.5862 - mean_absolute_error: 1.5862 - val_loss: 14.8214 - val_mean_absolute_error: 14.8214
#
# Epoch 00080: val_loss did not improve from 12.50318
# Epoch 81/100
# 105/105 [==============================] - 0s 601us/step - loss: 1.2021 - mean_absolute_error: 1.2021 - val_loss: 14.7576 - val_mean_absolute_error: 14.7576
#
# Epoch 00081: val_loss did not improve from 12.50318
# Epoch 82/100
# 105/105 [==============================] - 0s 687us/step - loss: 1.1320 - mean_absolute_error: 1.1320 - val_loss: 14.7454 - val_mean_absolute_error: 14.7454
#
# Epoch 00082: val_loss did not improve from 12.50318
# Epoch 83/100
# 105/105 [==============================] - 0s 625us/step - loss: 1.0319 - mean_absolute_error: 1.0319 - val_loss: 14.6238 - val_mean_absolute_error: 14.6238
#
# Epoch 00083: val_loss did not improve from 12.50318
# Epoch 84/100
# 105/105 [==============================] - 0s 622us/step - loss: 1.5423 - mean_absolute_error: 1.5423 - val_loss: 14.7128 - val_mean_absolute_error: 14.7128
#
# Epoch 00084: val_loss did not improve from 12.50318
# Epoch 85/100
# 105/105 [==============================] - 0s 606us/step - loss: 0.9951 - mean_absolute_error: 0.9951 - val_loss: 14.5088 - val_mean_absolute_error: 14.5088
#
# Epoch 00085: val_loss did not improve from 12.50318
# Epoch 86/100
# 105/105 [==============================] - 0s 640us/step - loss: 0.9561 - mean_absolute_error: 0.9561 - val_loss: 14.4630 - val_mean_absolute_error: 14.4630
#
# Epoch 00086: val_loss did not improve from 12.50318
# Epoch 87/100
# 105/105 [==============================] - 0s 634us/step - loss: 1.0377 - mean_absolute_error: 1.0377 - val_loss: 14.5195 - val_mean_absolute_error: 14.5195
#
# Epoch 00087: val_loss did not improve from 12.50318
# Epoch 88/100
# 105/105 [==============================] - 0s 582us/step - loss: 0.7501 - mean_absolute_error: 0.7501 - val_loss: 14.6755 - val_mean_absolute_error: 14.6755
#
# Epoch 00088: val_loss did not improve from 12.50318
# Epoch 89/100
# 105/105 [==============================] - 0s 656us/step - loss: 1.0442 - mean_absolute_error: 1.0442 - val_loss: 14.4995 - val_mean_absolute_error: 14.4995
#
# Epoch 00089: val_loss did not improve from 12.50318
# Epoch 90/100
# 105/105 [==============================] - 0s 613us/step - loss: 1.1998 - mean_absolute_error: 1.1998 - val_loss: 14.8402 - val_mean_absolute_error: 14.8402
#
# Epoch 00090: val_loss did not improve from 12.50318
# Epoch 91/100
# 105/105 [==============================] - 0s 627us/step - loss: 1.0696 - mean_absolute_error: 1.0696 - val_loss: 14.5613 - val_mean_absolute_error: 14.5613
#
# Epoch 00091: val_loss did not improve from 12.50318
# Epoch 92/100
# 105/105 [==============================] - 0s 609us/step - loss: 0.8869 - mean_absolute_error: 0.8869 - val_loss: 14.7472 - val_mean_absolute_error: 14.7472
#
# Epoch 00092: val_loss did not improve from 12.50318
# Epoch 93/100
# 105/105 [==============================] - 0s 608us/step - loss: 0.9381 - mean_absolute_error: 0.9381 - val_loss: 14.6052 - val_mean_absolute_error: 14.6052
#
# Epoch 00093: val_loss did not improve from 12.50318
# Epoch 94/100
# 105/105 [==============================] - 0s 589us/step - loss: 0.8447 - mean_absolute_error: 0.8447 - val_loss: 14.6721 - val_mean_absolute_error: 14.6721
#
# Epoch 00094: val_loss did not improve from 12.50318
# Epoch 95/100
# 105/105 [==============================] - 0s 649us/step - loss: 0.8818 - mean_absolute_error: 0.8818 - val_loss: 14.6321 - val_mean_absolute_error: 14.6321
#
# Epoch 00095: val_loss did not improve from 12.50318
# Epoch 96/100
# 105/105 [==============================] - 0s 611us/step - loss: 1.0556 - mean_absolute_error: 1.0556 - val_loss: 14.2994 - val_mean_absolute_error: 14.2994
#
# Epoch 00096: val_loss did not improve from 12.50318
# Epoch 97/100
# 105/105 [==============================] - 0s 654us/step - loss: 1.3056 - mean_absolute_error: 1.3056 - val_loss: 14.5119 - val_mean_absolute_error: 14.5119
#
# Epoch 00097: val_loss did not improve from 12.50318
# Epoch 98/100
# 105/105 [==============================] - 0s 617us/step - loss: 1.5149 - mean_absolute_error: 1.5149 - val_loss: 14.3547 - val_mean_absolute_error: 14.3547
#
# Epoch 00098: val_loss did not improve from 12.50318
# Epoch 99/100
# 105/105 [==============================] - 0s 598us/step - loss: 1.1258 - mean_absolute_error: 1.1258 - val_loss: 14.7498 - val_mean_absolute_error: 14.7498
#
# Epoch 00099: val_loss did not improve from 12.50318
# Epoch 100/100
# 105/105 [==============================] - 0s 592us/step - loss: 0.8057 - mean_absolute_error: 0.8057 - val_loss: 14.5417 - val_mean_absolute_error: 14.5417
#
# Epoch 00100: val_loss did not improve from 12.50318

# %%
predictions = NN_model.predict(X_test)
from sklearn.metrics import r2_score
accuracy=r2_score(Y_test,predictions)
print('test')
print(accuracy)
# Out:
# test
# 0.8741747941571797
