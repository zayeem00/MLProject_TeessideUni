# %% [markdown]
# <a href="https://colab.research.google.com/github/zayeem00/MLProject_TeessideUni/blob/master/CV_Ridge_LUSC_250_genes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Higher  values of alpha give better scores
import pandas as pd
import os
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import Lasso
from sklearn.linear_model import LassoCV

# %%
from google.colab import files
files.upload()

# %%
dt1=pd.read_excel('LUSC_250_NoDepth.xlsx')

# %%
dt1=dt1.set_index(dt1.columns[0])

# %%
from google.colab import files
files.upload()

# %%
tar=pd.read_excel('survival_LUAD.xlsx')

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import TimeSeriesSplit
from sklearn.model_selection import RepeatedKFold
from sklearn.linear_model import Ridge

# %%
 
import numpy as np
X=np.array(dt1)
y=np.array(tar)

# %%
 
tscv = TimeSeriesSplit(n_splits=10)

# %%
a=1
for train_index, test_index in tscv.split(X):
  print(a)
  #print("Train:", train_index, "Validation:", test_index)
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]
  ridgeReg=Ridge(alpha=1,normalize=True)
  ridgeReg.fit(X_train,y_train)
  predictions=ridgeReg.predict(X_test)
  print('train')
  print(ridgeReg.score(X_train,y_train))
  ridgeReg=Ridge(alpha=1,normalize=True)
  ridgeReg.fit(X_test,y_test)
  predictions=ridgeReg.predict(X_test)  
  print('test')
  print(ridgeReg.score(X_test,y_test))  
  a=a+1
# Out:
# 1
# train
# 0.9202697635843419
# test
# 0.9595377386813524
# 2
# train
# 0.7926408904147157
# test
# 0.9594189559431655
# 3
# train
# 0.7396279244596917
# test
# 0.9173274054630199
# 4
# train
# 0.5968642626530426
# test
# 0.9461916682540438
# 5
# train
# 0.5287004426762307
# test
# 0.9436373251239593
# 6
# train
# 0.47817584493967485
# test
# 0.9537642576947962
# 7
# train
# 0.4420440554508057
# test
# 0.9423454342084195
# 8
# train
# 0.3718082805994359
# test
# 0.9457637595053445
# 9
# train
# 0.3543143329283053
# test
# 0.9648613124885563
# 10
# train
# 0.31927964805726294
# test
# 0.9279231232966993

# %%
from sklearn.model_selection import KFold 
from sklearn.linear_model import ElasticNet
tscv = TimeSeriesSplit(n_splits=10)

# %%
a=1
for train_index, test_index in tscv.split(X):
  print(a)
  #print("Train:", train_index, "Validation:", test_index)
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = y[train_index], y[test_index]
  ridgeReg=Ridge(alpha=2,normalize=True)
  ridgeReg.fit(X_train,y_train)
  predictions=ridgeReg.predict(X_test)
  print('train')
  print(ridgeReg.score(X_train,y_train))
  ridgeReg=Ridge(alpha=2,normalize=True)
  ridgeReg.fit(X_test,y_test)
  predictions=ridgeReg.predict(X_test)  
  print('test')
  print(ridgeReg.score(X_test,y_test))  
  a=a+1
# Out:
# 1
# train
# 0.8231018300759843
# test
# 0.9029049579120796
# 2
# train
# 0.6607821492577464
# test
# 0.8988342947022118
# 3
# train
# 0.6135559841069939
# test
# 0.8244288902085604
# 4
# train
# 0.4754705786369721
# test
# 0.8716533132877055
# 5
# train
# 0.41164963128112614
# test
# 0.8669568075713703
# 6
# train
# 0.37040002606024164
# test
# 0.8929339434006694
# 7
# train
# 0.33929798743248063
# test
# 0.8597914551595941
# 8
# train
# 0.27486915534405165
# test
# 0.8708370647069668
# 9
# train
# 0.2603898274651749
# test
# 0.913555695140789
# 10
# train
# 0.23309023530750173
# test
# 0.8462666750274375

# %%
from sklearn.model_selection import KFold 
kf = RepeatedKFold(n_splits=5, n_repeats=10, random_state=None) 
a=1
for train_index, test_index in kf.split(X):
     # print("Train:", train_index, "Validation:",test_index)
      print(a)
      X_train, X_test = X[train_index], X[test_index] 
      y_train, y_test = y[train_index], y[test_index]
      ridgeReg=Ridge(alpha=2,normalize=True)
      ridgeReg.fit(X_train,y_train)
      predictions=ridgeReg.predict(X_test)
      print('train')
      print(ridgeReg.score(X_train,y_train))
      ridgeReg=Ridge(alpha=2,normalize=True)
      ridgeReg.fit(X_test,y_test)
      predictions=ridgeReg.predict(X_test)  
      print('test')
      print(ridgeReg.score(X_test,y_test))  
      a=a+1
# Out:
# 1
# train
# 0.28534656072820486
# test
# 0.6046926380269251
# 2
# train
# 0.2656734068072586
# test
# 0.6943874321574421
# 3
# train
# 0.24512027273126624
# test
# 0.6945420593623591
# 4
# train
# 0.24885064143393532
# test
# 0.6927458298558935
# 5
# train
# 0.28518762340870596
# test
# 0.6276844668490906
# 6
# train
# 0.27312559034446227
# test
# 0.5761880622277398
# 7
# train
# 0.26777194010058436
# test
# 0.6336225696053805
# 8
# train
# 0.2780962139202684
# test
# 0.5518414357474493
# 9
# train
# 0.2514763037818959
# test
# 0.709586886770294
# 10
# train
# 0.25361330756832157
# test
# 0.7066591452749336
# 11
# train
# 0.2617210793710907
# test
# 0.652149702951502
# 12
# train
# 0.24859126550600563
# test
# 0.6671998973057051
# 13
# train
# 0.30457388824415177
# test
# 0.6098765233532838
# 14
# train
# 0.24452176746647625
# test
# 0.6935168900305952
# 15
# train
# 0.25315090774339744
# test
# 0.6498420707832007
# 16
# train
# 0.27272524490644545
# test
# 0.525447129348799
# 17
# train
# 0.2564697675846821
# test
# 0.6666274353930175
# 18
# train
# 0.26284370814250535
# test
# 0.7179276567066158
# 19
# train
# 0.2665800320060596
# test
# 0.5905565746438237
# 20
# train
# 0.2496787254133891
# test
# 0.7280013942184768
# 21
# train
# 0.25757066998570055
# test
# 0.6253259099495987
# 22
# train
# 0.24907685543199332
# test
# 0.6880286530437825
# 23
# train
# 0.27506989109487057
# test
# 0.6767201659664761
# 24
# train
# 0.25951013601542317
# test
# 0.597187755241662
# 25
# train
# 0.2551790496818398
# test
# 0.5852373180824433
# 26
# train
# 0.2717393695570709
# test
# 0.5556817841198112
# 27
# train
# 0.2660718122659158
# test
# 0.6488341028543672
# 28
# train
# 0.25792792244452645
# test
# 0.6970860181325174
# 29
# train
# 0.26170783324045455
# test
# 0.7512605485586786
# 30
# train
# 0.2623873366768774
# test
# 0.65904360064393
# 31
# train
# 0.2779300931195232
# test
# 0.6778899635063897
# 32
# train
# 0.2771627734329667
# test
# 0.5956867321732704
# 33
# train
# 0.25658332850477183
# test
# 0.6288339812778506
# 34
# train
# 0.23795127214368672
# test
# 0.6765229743316852
# 35
# train
# 0.2628231592036644
# test
# 0.6489286971035151
# 36
# train
# 0.274346235345003
# test
# 0.6876837671708533
# 37
# train
# 0.2599227718306518
# test
# 0.6251215776762894
# 38
# train
# 0.2771141516100969
# test
# 0.6125955944625843
# 39
# train
# 0.26941474104205587
# test
# 0.6654018305657031
# 40
# train
# 0.24976466087643867
# test
# 0.705852865261827
# 41
# train
# 0.26031366010418255
# test
# 0.6534830662060537
# 42
# train
# 0.2691099523197775
# test
# 0.6331320529536092
# 43
# train
# 0.26409222797331444
# test
# 0.6535851255728269
# 44
# train
# 0.24093095567970146
# test
# 0.691187031724162
# 45
# train
# 0.2780945576542537
# test
# 0.6350287985780179
# 46
# train
# 0.2582037458544394
# test
# 0.671137744531725
# 47
# train
# 0.26898029871210827
# test
# 0.6547737868500816
# 48
# train
# 0.27166385191998454
# test
# 0.5820062425800379
# 49
# train
# 0.266989617534942
# test
# 0.6493031522451933
# 50
# train
# 0.25507342092810736
# test
# 0.7300280403761762

# %%
from sklearn.model_selection import KFold 
kf = RepeatedKFold(n_splits=5, n_repeats=10, random_state=None) 
a=1
for train_index, test_index in kf.split(X):
     # print("Train:", train_index, "Validation:",test_index)
      print(a)
      X_train, X_test = X[train_index], X[test_index] 
      y_train, y_test = y[train_index], y[test_index]
      ridgeReg=Ridge(alpha=1,normalize=True)
      ridgeReg.fit(X_train,y_train)
      predictions=ridgeReg.predict(X_test)
      print('train')
      print(ridgeReg.score(X_train,y_train))
      ridgeReg=Ridge(alpha=1,normalize=True)
      ridgeReg.fit(X_test,y_test)
      predictions=ridgeReg.predict(X_test)  
      print('test')
      print(ridgeReg.score(X_test,y_test))  
      a=a+1
# Out:
# 1
# train
# 0.34657030363967734
# test
# 0.7901218575806507
# 2
# train
# 0.32846953317171645
# test
# 0.7658983334136199
# 3
# train
# 0.357783090491849
# test
# 0.8179086456906037
# 4
# train
# 0.3373351618878997
# test
# 0.7792145716414559
# 5
# train
# 0.38877045890846895
# test
# 0.7653652473183474
# 6
# train
# 0.3531059893508043
# test
# 0.7721636612788152
# 7
# train
# 0.359311860113372
# test
# 0.8062487715578477
# 8
# train
# 0.37977975432492855
# test
# 0.7424790627828808
# 9
# train
# 0.34026201880958806
# test
# 0.7683186150864081
# 10
# train
# 0.33654018617237924
# test
# 0.7873316930837161
# 11
# train
# 0.36636368106418793
# test
# 0.770455730137357
# 12
# train
# 0.36444659283085723
# test
# 0.7644477217869645
# 13
# train
# 0.34370113408200087
# test
# 0.8479120588481666
# 14
# train
# 0.34820455005477424
# test
# 0.7663271178803817
# 15
# train
# 0.32473953599107075
# test
# 0.7746513537428423
# 16
# train
# 0.3553336391500955
# test
# 0.8255312730798665
# 17
# train
# 0.35983430951376427
# test
# 0.8210433668579935
# 18
# train
# 0.3616698594790899
# test
# 0.7020373428631058
# 19
# train
# 0.34536314274303076
# test
# 0.788760482854383
# 20
# train
# 0.35210342989390764
# test
# 0.8105993099366454
# 21
# train
# 0.3605209300619462
# test
# 0.7740682426667318
# 22
# train
# 0.3700225061184289
# test
# 0.7660368636262427
# 23
# train
# 0.33690221151393573
# test
# 0.7743373829544851
# 24
# train
# 0.3562977320566698
# test
# 0.7700831804027508
# 25
# train
# 0.3363494302311222
# test
# 0.8143295664011163
# 26
# train
# 0.3793369830332229
# test
# 0.7246850977556897
# 27
# train
# 0.344441223747023
# test
# 0.7617869706310921
# 28
# train
# 0.3362794997325297
# test
# 0.7572563315813675
# 29
# train
# 0.3687923750793318
# test
# 0.7582951735897779
# 30
# train
# 0.318721971314191
# test
# 0.8325017449444362
# 31
# train
# 0.3484687990292986
# test
# 0.7473525466322799
# 32
# train
# 0.36823514122198825
# test
# 0.7642529198352132
# 33
# train
# 0.33521519956736456
# test
# 0.8396605055582744
# 34
# train
# 0.3533429065769371
# test
# 0.7400992085914324
# 35
# train
# 0.359237572488049
# test
# 0.7587116349393094
# 36
# train
# 0.3463004926842934
# test
# 0.7596158746268936
# 37
# train
# 0.3410779768710763
# test
# 0.8686938833834879
# 38
# train
# 0.3590503737445794
# test
# 0.7426666156607048
# 39
# train
# 0.3645092775444904
# test
# 0.8346636676440553
# 40
# train
# 0.35797353228583495
# test
# 0.7921470777110933
# 41
# train
# 0.36492278947327395
# test
# 0.7511041630122902
# 42
# train
# 0.35996343401804354
# test
# 0.7259894197002376
# 43
# train
# 0.3323260371241237
# test
# 0.791561832482806
# 44
# train
# 0.3295858486032308
# test
# 0.8649363532724219
# 45
# train
# 0.36208709965166963
# test
# 0.7048704320390022
# 46
# train
# 0.3669418316709152
# test
# 0.7557590194735424
# 47
# train
# 0.3404551122575573
# test
# 0.7765955563550224
# 48
# train
# 0.3482338050840986
# test
# 0.8673756381318091
# 49
# train
# 0.38264541250864403
# test
# 0.7391730335864038
# 50
# train
# 0.3384624275937783
# test
# 0.8076285610482256
